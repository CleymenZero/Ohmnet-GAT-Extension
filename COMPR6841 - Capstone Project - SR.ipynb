# %% [markdown]
# Required Imports.

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.data import Data
from torch_geometric.loader import LinkNeighborLoader
import networkx as nx
import os
import pandas as pd
import torch_geometric as torch_g
from torch_geometric.nn import Node2Vec
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score
from pathlib import Path
import pronto
from pronto import Ontology
import gc
import platform

print(f"--- Environment Versions ---")
print(f"Python:       {platform.python_version()}")
print(f"PyTorch:      {torch.__version__}")
print(f"PyG (PyTorch Geometric): {torch_g.__version__}")
print(f"Pandas:       {pd.__version__}")
print(f"Matplotlib:   {plt.matplotlib.__version__}")
print(f"NetworkX:     {nx.__version__}")
print(f"Scikit-Learn: {sklearn.__version__}")
print(f"Pronto:       {pronto.__version__}")
if torch.cuda.is_available():
    # Get the ID of the current device
    device_id = torch.cuda.current_device()
    
    # Get properties
    props = torch.cuda.get_device_properties(device_id)
    
    # Get memory info (returns bytes, so we convert to GB)
    free_mem, total_mem = torch.cuda.mem_get_info()
    
    print(f"--- GPU Specifications ---")
    print(f"Name:              {props.name}")
    print(f"Compute Capability: {props.major}.{props.minor}")
    print(f"Total VRAM:        {total_mem / 1024**3:.2f} GB")
    print(f"Available VRAM:    {free_mem / 1024**3:.2f} GB")
    print(f"Cores (SMs):       {props.multi_processor_count}")
else:
    print("No CUDA GPU detected.")
# Out:
# --- Environment Versions ---
# Python:       3.12.3
# PyTorch:      2.5.1+cu121
# PyG (PyTorch Geometric): 2.7.0
# Pandas:       3.0.0
# Matplotlib:   3.10.8
# NetworkX:     3.6.1
# Scikit-Learn: 1.8.0
# Pronto:       2.7.3
# --- GPU Specifications ---
# Name:              NVIDIA GeForce RTX 3090 Ti
# Compute Capability: 8.6
# Total VRAM:        23.99 GB
# Available VRAM:    22.74 GB
# Cores (SMs):       84

# %% [markdown]
# **EDA**
# We know so far the following:
# - 144 tissues were used to train with the algorithm and 107 leaf tissues were used to test in the Ohmnet study

# %% [markdown]
# **Exploring the data files**

# %% [markdown]
# *Tissue hierarchy*

# %%
data_dir = Path('./data')

pd.read_csv(data_dir / 'tissue.hierarchy', sep='\t', header=None)
# Out:
#                     0                 1
# 0         BTO:0001388  BTO:0000203_NODE
# 1         BTO:0001387  BTO:0000753_NODE
# 2    BTO:0003099_NODE  BTO:0000083_NODE
# 3    BTO:0003092_NODE  BTO:0003091_NODE
# 4    BTO:0003091_NODE         Root_NODE
# ..                ...               ...
# 213       BTO:0002295  BTO:0001515_NODE
# 214       BTO:0000562  BTO:0000088_NODE
# 215       BTO:0000620  BTO:0000651_NODE
# 216       BTO:0000199  BTO:0001369_NODE
# 217  BTO:0000389_NODE  BTO:0000975_NODE
#
# [218 rows x 2 columns]

# %% [markdown]
# BRENDA Tissue Ontology (BTO) file

# %%
onto = Ontology(str(data_dir / 'BrendaTissue.obo'))

#Print target tissue ontology
target_ids = ["BTO:0001388", "BTO:0000203"]
for tid in target_ids:
    if tid in onto:
        t = onto[tid]
        print(f"{t.id} -> {t.name}")
    else:
        print(f"{tid} not found in ontology")
target_ids = ["BTO:0001387", "BTO:0000753"]
for tid in target_ids:
    if tid in onto:
        t = onto[tid]
        print(f"{t.id} -> {t.name}")
    else:
        print(f"{tid} not found in ontology")
print("\n")
with open(data_dir / 'BrendaTissue.obo', 'r', encoding='utf-8') as f:
    for i in range(20):
        print(f.readline().strip())
# Out:
# BTO:0001388 -> trachea
# BTO:0000203 -> respiratory system
# BTO:0001387 -> tonsil
# BTO:0000753 -> lymphoid tissue
#
#
# format-version: 1.2
# date: 03:05:2016 09:39
# saved-by: Marion, contact@brenda-enzymes.org
# auto-generated-by: OBO-Edit 2.3.1
# synonymtypedef: GE "LANGUAGE GERMAN"
# synonymtypedef: SCI "SCIENTIFIC NAME"
# default-namespace: BrendaTissueOBO
# remark: www.brenda-enzymes.org
#
# [Term]
# id: BTO:0000000
# name: tissues, cell types and enzyme sources
# def: "A structured controlled vocabulary for the source of an enzyme. It comprises terms of tissues, cell lines, cell types and cell cultures from uni- and multicellular organisms." [curators:mgr]
#
# [Term]
# id: BTO:0000001
# name: culture condition:-induced cell
# is_a: BTO:0000216 ! culture condition
#
# [Term]

# %% [markdown]
# *Vizualizing tissue.edges file*

# %%
pd.read_csv(data_dir / 'tissue.edges', sep='\t', header=None) #seems to simply be a name representation of tissue.hierarchy without the BTO
# Out:
#                               0                         1
# 0                       Trachea         RespiratorySystem
# 1                        Tonsil            LymphoidTissue
# 2    InternalFemaleGenitalOrgan  FemaleReproductiveSystem
# 3                 UrinarySystem          UrogenitalSystem
# 4              UrogenitalSystem                      Root
# ..                          ...                       ...
# 213                    Podocyte      GlomerularEpithelium
# 214                       Heart      CardiovascularSystem
# 215                       Ileum            SmallIntestine
# 216               CardiacMuscle  VertebrateMuscularSystem
# 217       MatureOvarianFollicle                     Ovary
#
# [218 rows x 2 columns]

# %% [markdown]
# *Vizualizing PPT-Ohmnet_tissues-combined.edgelist*

# %%
df_PPI = pd.read_csv(data_dir / 'PPT-Ohmnet_tissues-combined.edgelist', sep='\t') #Contains 3666563 PPIs and their respective tissue from the 144 tissues of the Ohmnet study
df_PPI #noticing the tissues like "urinary_bladder" might need formatting to match BTO nomenclature
# Out:
#          # protein1  protein2           tissue
# 0              4790     79155  urinary_bladder
# 1             26039      6597  urinary_bladder
# 2             57154      3309  urinary_bladder
# 3              6631      9775  urinary_bladder
# 4              1855      8312  urinary_bladder
# ...             ...       ...              ...
# 3666558        6045      1153     spermatocyte
# 3666559       10616      1387     spermatocyte
# 3666560        2033      7026     spermatocyte
# 3666561         324      1457     spermatocyte
# 3666562         267       488     spermatocyte
#
# [3666563 rows x 3 columns]

# %% [markdown]
# *Unique tissues*

# %%
unique_tissues = df_PPI['tissue'].unique() #here are the 144 tissues used for training in the Ohmnet study, the 107 leaf tissues will need to be isolated on the basis of the parent-children relationship
print(unique_tissues)
# Out:
# <StringArray>
# [                'urinary_bladder',                    'hypothalamus',
#                            'colon', 'umbilical_vein_endothelial_cell',
#                            'brain',                          'tonsil',
#                   'nervous_system',                       'forebrain',
#                         'placenta',                          'neuron',
#  ...
#                          'oviduct',         'hematopoietic_stem_cell',
#                       'cerebellum',                     'bone_marrow',
#                         'bronchus',                 'skin_fibroblast',
#                  'skeletal_muscle',       'vascular_endothelial_cell',
#                           'muscle',                    'spermatocyte']
# Length: 144, dtype: str

# %% [markdown]
# *Clear the memory*

# %%
del unique_tissues
del df_PPI
gc.collect()
# Out:
# 1843

# %% [markdown]
# **The plan is as follows:**
#
# 1. Load the tissue.hierarchy file using networkx and use it to build a directed graph
# 2. Sort the tissue graph into a list of NodeView object for indexing
# 3. Index the tissues for reproducibility and easy edge list creation
# 4. Create the edge list of indexed tuples using the indexed NodeView object with source and destination
# 5. Transform the python list into a tensor and make it contiguous in memory for faster training
# 6. Create node2vec model with:
#     - 256 embeddings to start (there are 219 tissues so I want to allow sufficient "mathematical space", 128 might be too small and 512 might be too inefficient)
#     - walk length=20 -> the number of hops the model will do
#     - context_size=10 -> how many nodes the model looks at at every node, 10 is probably too high given the way the tissues are organized
#     - walks_per_node=10 -> model simulates 10 walks per node
#     - num_negative_samples=1 -> for each connected node pair, sample 1 negative node pair to see what not to learn
#     - p=1, q=1 -> unbiased in terms of p: high p = move away, low p: stay near origin; high q: walk samples neighborhood, low q: walk explores long paths (depth-first search type)
#     - sparse=True -> since a lot of the tissues are not connected, this will lead to sparse fewer calculations because only a few tissues' embeddings are being updated each step; makes it much faster and uses less memory
#     - num_nodes=len(tissue_nodes) -> tell the model how many nodes thre are
# 7. Initialize the embeddings to a xavier_normal_ distribution (introduced after troubleshooting the observation of astronomical losses and that model didn't train well)
# 8. put the model on GPU (already defined 'device' to be device agnostic)
# 9. define a dataloader to create batches of walks, define an optimizer, determine a number of epochs
# 10. define a training loop to train the model -> I deliberately delete the positive and negative random walks to save memory
# 11. print results

# %% [markdown]
# *Load Tissue Hierarchy for construction of tissue graph to train on the entire tissue hierarchy.*

# %%
tissue_graph = nx.read_edgelist(data_dir / 'tissue.hierarchy', create_using=nx.DiGraph())
tissue_nodes = sorted(list(tissue_graph.nodes()))

node_to_idx_tissue = {}
for idx, node in enumerate(tissue_nodes):
    node_to_idx_tissue[node] = idx

edges_tissue = []
for src, dst in tissue_graph.edges():
    src_index = node_to_idx_tissue[src]
    dst_index = node_to_idx_tissue[dst]
    edges_tissue.append((src_index, dst_index)) 
print(f"edges format: {edges_tissue}")

edges_index_tissue = torch.tensor(edges_tissue, dtype=torch.long).t().contiguous()

print(f"Shape of edges_index_tissue: {edges_index_tissue.shape}")
print(f"Number of tissues: {len(tissue_nodes)}")

#edges_index_tissue shape is ([2,218]) so we have 218 and len(tissue_nodes) is 219 meaning we have 219 tissue nodes
# Out:
# edges format: [(172, 34), (34, 218), (171, 106), (106, 218), (211, 9), (9, 7), (209, 208), (208, 218), (210, 8), (8, 7), (88, 126), (126, 218), (195, 70), (70, 33), (117, 68), (68, 218), (194, 94), (94, 76), (160, 106), (116, 29), (29, 167), (40, 185), (185, 218), (196, 67), (67, 22), (139, 211), (140, 16), (16, 191), (138, 42), (42, 100), (192, 65), (65, 93), (33, 218), (35, 187), (187, 218), (200, 121), (121, 183), (201, 52), (52, 71), (72, 31), (31, 49), (71, 43), (43, 45), (6, 190), (190, 218), (142, 218), (143, 106), (183, 26), (120, 86), (86, 84), (119, 105), (105, 86), (47, 212), (212, 199), (161, 76), (76, 218), (46, 35), (147, 158), (158, 152), (64, 93), (93, 218), (150, 70), (163, 22), (22, 34), (30, 101), (101, 94), (107, 100), (100, 28), (108, 56), (56, 189), (49, 0), (0, 218), (188, 68), (186, 218), (134, 95), (95, 56), (214, 175), (175, 61), (166, 54), (54, 26), (165, 80), (80, 9), (167, 218), (168, 186), (28, 26), (26, 40), (25, 187), (24, 68), (27, 44), (44, 185), (110, 185), (112, 111), (111, 143), (207, 196), (131, 211), (199, 92), (15, 12), (12, 84), (14, 190), (17, 81), (81, 105), (191, 31), (216, 111), (182, 217), (217, 15), (129, 8), (130, 6), (75, 71), (159, 40), (157, 102), (102, 147), (152, 8), (128, 127), (127, 31), (154, 93), (155, 93), (173, 28), (50, 70), (124, 216), (99, 209), (189, 77), (77, 218), (153, 84), (84, 218), (177, 179), (179, 211), (178, 179), (11, 218), (7, 208), (10, 30), (53, 125), (125, 99), (79, 53), (97, 96), (96, 94), (206, 88), (38, 218), (202, 39), (39, 38), (135, 71), (92, 58), (58, 33), (59, 31), (136, 185), (87, 108), (85, 145), (145, 141), (90, 41), (41, 45), (89, 54), (203, 160), (61, 65), (62, 142), (63, 81), (137, 126), (115, 119), (82, 184), (184, 64), (45, 26), (36, 66), (66, 44), (37, 66), (198, 61), (197, 61), (141, 11), (118, 182), (74, 26), (73, 131), (3, 69), (69, 77), (4, 5), (5, 189), (1, 107), (2, 100), (162, 44), (113, 111), (148, 210), (122, 186), (146, 186), (144, 28), (164, 71), (51, 60), (60, 131), (133, 56), (132, 211), (169, 149), (149, 113), (170, 189), (109, 34), (48, 194), (21, 145), (18, 81), (19, 12), (20, 118), (23, 28), (156, 186), (103, 70), (104, 15), (114, 106), (215, 202), (213, 65), (123, 179), (176, 14), (174, 139), (13, 110), (204, 44), (78, 40), (98, 64), (151, 142), (181, 120), (180, 29), (55, 125), (193, 24), (57, 96), (205, 192), (83, 11), (91, 96), (32, 168)]
# Shape of edges_index_tissue: torch.Size([2, 218])
# Number of tissues: 219

# %% [markdown]
# *Generating embeddings for tissue hierarchy*

# %%
node2vec_engine = Node2Vec(
    edges_index_tissue,
    embedding_dim=256,
    walk_length=20,
    context_size=10,
    walks_per_node=10,
    num_negative_samples=1,
    p=1, q=1,
    sparse=True,
    num_nodes=len(tissue_nodes) # Explicitly pass num_nodes
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

torch.nn.init.xavier_normal_(node2vec_engine.embedding.weight)
node2vec_engine = node2vec_engine.to(device)

print("Training Node2Vec embeddings...")
loader = node2vec_engine.loader(batch_size=32, shuffle=True, num_workers=0)
optimizer_n2v = torch.optim.SparseAdam(list(node2vec_engine.parameters()), lr=0.01)

node2vec_epochs = 1000
for epoch in range(1, node2vec_epochs + 1):
    node2vec_engine.train()
    total_loss = 0
    for pos_rw, neg_rw in loader:
        optimizer_n2v.zero_grad()
        loss_n2v = node2vec_engine.loss(pos_rw.to(device), neg_rw.to(device))
        loss_n2v.backward()
        optimizer_n2v.step()
        total_loss += loss_n2v.item()
        
        # --- Memory Management ---
        del pos_rw, neg_rw, loss_n2v
            
    if epoch % 100 == 0:
        print(f"  Node2Vec Epoch: {epoch:03d}, Loss: {total_loss / len(loader):.4f}")
print("Node2Vec training complete.")
# Out:
# Training Node2Vec embeddings...
#   Node2Vec Epoch: 100, Loss: 0.7664
#   Node2Vec Epoch: 200, Loss: 0.7549
#   Node2Vec Epoch: 300, Loss: 0.7508
#   Node2Vec Epoch: 400, Loss: 0.7460
#   Node2Vec Epoch: 500, Loss: 0.7476
#   Node2Vec Epoch: 600, Loss: 0.7441
#   Node2Vec Epoch: 700, Loss: 0.7482
#   Node2Vec Epoch: 800, Loss: 0.7478
#   Node2Vec Epoch: 900, Loss: 0.7462
#   Node2Vec Epoch: 1000, Loss: 0.7455
# Node2Vec training complete.

# %% [markdown]
# *Saving embeddings*

# %%
node2vec_engine = node2vec_engine.to('cpu')

embeddings = node2vec_engine.embedding.weight.data

torch.save(node2vec_engine.state_dict(), 'node2vec_model.pth')

print("Embeddings saved successfully to node2vec_model.pth")
# Out:
# Embeddings saved successfully to node2vec_model.pth

# %% [markdown]
# *Load embeddings*

# %%
# Re-initialize the model shell with the EXACT same parameters
node2vec_engine = Node2Vec(
    edges_index_tissue,
    embedding_dim=256,
    walk_length=20,
    context_size=10,
    walks_per_node=10,
    num_negative_samples=1,
    p=1, q=1,
    sparse=True,
    num_nodes=len(tissue_nodes)
)

# Load the state dictionary from the file
state_dict = torch.load('node2vec_model.pth')

# Apply the state dictionary to your new model
node2vec_engine.load_state_dict(state_dict)

# Set it to evaluation mode (if you are done training)
node2vec_engine.eval()

print("Model loaded successfully!")
# Out:
# Model loaded successfully!
# C:\Users\steve\AppData\Local\Temp\ipykernel_11132\3846122681.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('node2vec_model.pth')

# %% [markdown]
# **Next Steps**
# 1. Put the model on CPU if it's on GPU
# 2. Extract the raw embeddings from the model
# 3. Make Root_NODE the root of the tree as in, use its embeddings as the root embeddings
# 4. Set Root_NODE as the root of the tree
# 5. Setup the data pipeline from the PPI and map the tissues to the embeddings
# 6. Map tissue names to BTO by stripping the file
# 7. Map processed tissue names to their unique hierarchy indices.
# 8. Group PPI records by protein pairs to create a multi-label target matrix.
# 9. Split the interaction data into training, validation, and test sets.
# 10. Instantiate graph loaders for spatial neighborhood sampling.
# 11. Define the LateFusionGAT architecture and hierarchical penalty loss.
# 12. Train the model and evaluate performance using ROCAUC and F1 scores.

# %% [markdown]
# *Taking the raw weights from the embeddings and set Root_NODE as the root node of the tree*

# %%
node2vec_engine = node2vec_engine.to('cpu') #if save model cell is not run we still need to move the model to CPU

tissue_embeddings_raw = node2vec_engine.embedding.weight.data

if 'Root_NODE' in node_to_idx_tissue:
    root_node_idx = node_to_idx_tissue['Root_NODE']
    global_tissue_address = tissue_embeddings_raw[root_node_idx].unsqueeze(0)
else:
    global_tissue_address = tissue_embeddings_raw.mean(dim=0, keepdim=True)
global_tissue_address = global_tissue_address.to('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# *Setting up the data pipeline from the 3.6M PPI file*

# %%
print("Setting up data pipeline...")
ppi_file_path = data_dir / 'PPT-Ohmnet_tissues-combined.edgelist'
df = pd.read_csv(ppi_file_path, sep='\t', header=0, names=['protein_a', 'protein_b', 'tissue'])

unique_proteins = pd.concat([df['protein_a'], df['protein_b']]).unique()
protein_to_idx = {prot: i for i, prot in enumerate(unique_proteins)}
num_unique_proteins = len(unique_proteins)

# Use the same 'tissue_nodes' list from Node2Vec setup for consistency
num_tissues = len(tissue_nodes) # This is 144 tissues

df['p1_idx'] = df['protein_a'].map(protein_to_idx)
df['p2_idx'] = df['protein_b'].map(protein_to_idx)
# Out:
# Setting up data pipeline...

# %% [markdown]
# *BTO mapping begins here: strip id and name from file and build a searchable dictionary*

# %%
print("Building Name-to-BTO mapping from BrendaTissue.obo...")
obo_path = data_dir / 'BrendaTissue.obo'
name_to_bto = {}
if obo_path.exists():
    with open(obo_path, 'r', encoding='utf-8') as f:
        cid = None
        for line in f:
            line = line.strip()
            if line.startswith('id: '): cid = line[4:]
            elif line.startswith('name: ') and cid: name_to_bto[line[6:].lower()] = cid
# Out:
# Building Name-to-BTO mapping from BrendaTissue.obo...

# %% [markdown]
# *Problem discovered in function to map BTO tissues to dataset -> I was losing 70k PPIs and manually setting those to find the proper tissues*
# I found the IDs by inspecting the obo file and the PPI dataset and noticed dicrepancies in the naming of the tissues in both files.

# %%
manual_rescue = {
    'culture condition cd8 cell': 'BTO:0004410',
    'b lymphocyte': 'BTO:0000776',  # UPDATED ID
    'b lymphocytes': 'BTO:0000776', # UPDATED ID
    't lymphocyte': 'BTO:0000782',  # UPDATED ID
    't lymphocytes': 'BTO:0000782'  # UPDATED ID
}

# %% [markdown]
# *Function to reformat the tissue names in the PPI dataset to the BTO names then search both manual rescue and the name:BTO_id dictionary for matches*

# %%
def map_tissue(t_name):
    # Normalize: 'urinary_bladder' -> 'urinary bladder'
    search_name = str(t_name).lower().replace('_', ' ')
    
    # Check Manual Rescue
    if search_name in manual_rescue:
        bto_id = manual_rescue[search_name]
    else:
        bto_id = name_to_bto.get(search_name)
    
    if not bto_id:
        return None
    
    # Map to Hierarchy Index
    if bto_id in node_to_idx_tissue:
        return node_to_idx_tissue[bto_id]
    if bto_id + '_NODE' in node_to_idx_tissue:
        return node_to_idx_tissue[bto_id + '_NODE']
    
    return None

# %% [markdown]
# *Map dataset tissues to tissue_idx from Node2Vec*

# %%
print("Setting up data pipeline and mapping indices...")
ppi_file_path = data_dir / 'PPT-Ohmnet_tissues-combined.edgelist'
# 1. Load the raw data
df = pd.read_csv(ppi_file_path, sep='\t', header=0, names=['protein_a', 'protein_b', 'tissue'])
# 2. Map PROTEINS to indices (This creates the missing 'p1_idx' and 'p2_idx')
unique_proteins = pd.concat([df['protein_a'], df['protein_b']]).unique()
protein_to_idx = {prot: i for i, prot in enumerate(unique_proteins)}
num_unique_proteins = len(unique_proteins)
df['p1_idx'] = df['protein_a'].map(protein_to_idx)
df['p2_idx'] = df['protein_b'].map(protein_to_idx)
# 3. Map TISSUES to indices
df['t_idx'] = df['tissue'].map(map_tissue)
# 4. Filter out any unmapped records
original_len = len(df)
df = df.dropna(subset=['t_idx', 'p1_idx', 'p2_idx']).copy()
df['t_idx'] = df['t_idx'].astype(int)
# 5. Summary
new_mapped_count = len(df)
print(f"Mapped {new_mapped_count}/{original_len} PPI records successfully.")
# Out:
# Setting up data pipeline and mapping indices...
# Mapped 3666563/3666563 PPI records successfully.

# %% [markdown]
# *Protein-Protein-Tissues grouping to collapse 3.6M rows 70.3k rows*

# %%
# Group by protein pair and collect all tissues they interact in
grouped = df.groupby(['p1_idx', 'p2_idx'])['t_idx'].apply(list).reset_index()
# Create edge index for PyTorch
source_nodes_all = torch.tensor(grouped['p1_idx'].values, dtype=torch.long)
target_nodes_all = torch.tensor(grouped['p2_idx'].values, dtype=torch.long)
edge_index_all_ppi = torch.stack([source_nodes_all, target_nodes_all], dim=0)
# Create the Multi-Hot target matrix
# (Ensure num_tissues is defined, usually 219)
y_targets_all_ppi = torch.zeros((len(grouped), num_tissues), dtype=torch.float)
for row_idx, tissues in enumerate(grouped['t_idx']):
    y_targets_all_ppi[row_idx, tissues] = 1.0
protein_indices_all = torch.arange(num_unique_proteins, dtype=torch.long)
print(f"Grouped shape: {grouped.shape}")
print(f"Number of unique protein interactions: {len(grouped)}")
# Out:
# Grouped shape: (70338, 3)
# Number of unique protein interactions: 70338

# %% [markdown]
# *Consolidating PPI Network into PyTorch Geometric Data Object*

# %%
full_graph_data = Data(
    x=protein_indices_all,
    edge_index=edge_index_all_ppi # Full PPI graph structure for sampling
)

# %% [markdown]
# *Train-Val-Test split: 80% for training, 10% for validation and 10% for testing*

# %%
num_unique_ppis = len(grouped)
all_indices = torch.arange(num_unique_ppis, dtype=torch.long)

train_indices, test_val_indices = train_test_split(all_indices, test_size=0.2, random_state=42)
val_indices, test_indices = train_test_split(test_val_indices, test_size=0.5, random_state=42) # 0.5 of 20% = 10%

print(f"Total unique PPIs: {num_unique_ppis}")
print(f"Train PPIs: {len(train_indices)}")
print(f"Validation PPIs: {len(val_indices)}")
print(f"Test PPIs: {len(test_indices)}")
# Out:
# Total unique PPIs: 70338
# Train PPIs: 56270
# Validation PPIs: 7034
# Test PPIs: 7034

# %% [markdown]
# *Identifying the leaf nodes used for inference*

# %%
leaf_node_names = [node for node in tissue_graph.nodes() if tissue_graph.in_degree(node) == 0 and node != 'Root_NODE']
leaf_node_indices = torch.tensor([node_to_idx_tissue[name] for name in leaf_node_names if name in node_to_idx_tissue], dtype=torch.long)
print(f"Identified {len(leaf_node_indices)} leaf nodes for test set masking.")
# Out:
# Identified 107 leaf nodes for test set masking.

# %% [markdown]
# *Instantiating the data_loaders*

# %%
train_loader = LinkNeighborLoader(
    full_graph_data,
    num_neighbors=[15, 10],
    batch_size=1024,
    edge_label_index=edge_index_all_ppi[:, train_indices], # Only sample edges from training split
    edge_label=y_targets_all_ppi[train_indices],           # Corresponding labels
    shuffle=True,
)

val_loader = LinkNeighborLoader(
    full_graph_data,
    num_neighbors=[15, 10],
    batch_size=1024, # Can use a larger batch size for validation if VRAM allows
    edge_label_index=edge_index_all_ppi[:, val_indices],
    edge_label=y_targets_all_ppi[val_indices],
    shuffle=False,
)

test_loader = LinkNeighborLoader(
    full_graph_data,
    num_neighbors=[15, 10],
    batch_size=1024,
    edge_label_index=edge_index_all_ppi[:, test_indices],
    edge_label=y_targets_all_ppi[test_indices],
    shuffle=False,
)
print("Train, Validation, Test loaders ready.")
# Out:
# Train, Validation, Test loaders ready.

# %% [markdown]
# *Prepare Hierarchical Pairs for customLoss Function.*

# %%
hierarchical_pairs_list = []
for child_name, parent_name in tissue_graph.edges():
    child_idx = node_to_idx_tissue[child_name]
    parent_idx = node_to_idx_tissue[parent_name]
    hierarchical_pairs_list.append((child_idx, parent_idx))
hierarchical_pairs = torch.tensor(hierarchical_pairs_list, dtype=torch.long)

# %% [markdown]
# *Define the loss function for tissue embeddings*

# %%
def custom_loss(y_hat, y_true, hierarchical_pairs_tensor, lambda_penalty=0.1):
    bce_loss = F.binary_cross_entropy(y_hat, y_true)
    
    children_probs = y_hat[:, hierarchical_pairs_tensor[:, 0]]
    parents_probs = y_hat[:, hierarchical_pairs_tensor[:, 1]]
    
    # We use mean() instead of sum() to make penalty independent of batch size
    violations = torch.clamp(children_probs - parents_probs, min=0.0)
    penalty = lambda_penalty * torch.mean(violations)
    
    return bce_loss + penalty

# %% [markdown]
# *Defining the late fusion GAT*

# %%
class LateFusionGAT(nn.Module):
    def __init__(self, num_proteins, protein_embedding_dim,
                 num_heads, gat_hidden_channels, gat_output_channels,
                 tissue_address_dim, mlp_hidden_channels, num_tissues,
                 global_tissue_address_tensor, dropout_rate=0.3):
        super(LateFusionGAT, self).__init__()

        self.protein_embedding = nn.Embedding(num_proteins, protein_embedding_dim)

        self.gat1 = GATConv(
            in_channels=protein_embedding_dim,
            out_channels=gat_hidden_channels,
            heads=num_heads,
            dropout=dropout_rate,
            add_self_loops=False,
            negative_slope=0.2
        )
        self.gat2 = GATConv(
            in_channels=gat_hidden_channels * num_heads,
            out_channels=gat_output_channels,
            heads=1,
            dropout=dropout_rate,
            add_self_loops=False
        )
        
        self.global_tissue_address = nn.Parameter(global_tissue_address_tensor, requires_grad=False)
        
        mlp_input_dim = (gat_output_channels * 2) + tissue_address_dim

        self.mlp = nn.Sequential(
            nn.Linear(mlp_input_dim, mlp_hidden_channels),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(mlp_hidden_channels, mlp_hidden_channels // 2),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(mlp_hidden_channels // 2, num_tissues)
        )

    def forward(self, batch):
        x = batch.x
        edge_index = batch.edge_index
        
        # Note: LinkNeighborLoader automatically remaps edge_label_index 
        # to local indices relative to the sampled batch (x).
        protein_a_indices = batch.edge_label_index[0]
        protein_b_indices = batch.edge_label_index[1]

        x_embedded = self.protein_embedding(x)

        x_gat = F.elu(self.gat1(x_embedded, edge_index))
        x_gat = self.gat2(x_gat, edge_index)

        # Directly index using the remapped edge_label_index
        emb_protein_a = x_gat[protein_a_indices]
        emb_protein_b = x_gat[protein_b_indices]

        batch_size = emb_protein_a.shape[0]
        repeated_tissue_address = self.global_tissue_address.repeat(batch_size, 1)

        concatenated_features = torch.cat(
            (emb_protein_a, emb_protein_b, repeated_tissue_address),
            dim=-1
        )

        raw_predictions = self.mlp(concatenated_features)
        probabilities = torch.sigmoid(raw_predictions)
        
        return probabilities

# %% [markdown]
# **Training, Validation and Testing Plan:**
# 1. define architectural hyperparameters
# 2. Instantiate the model
# 3. Instantiate the optimizer
# 4. Define the number of epochs and because we plan to use early stopping, define patience and initialize early_stop_counter to 0
# 5. Elaborate the training loop:
#     - Set model to train, initialize a training loss accumulator
#     - Inside for loop (training):
#         - send batch to device
#         - call optimizer.zero_grad()
#         - generate predictions with model(batch)
#         - calculate loss using custom loss function with predictions, the tissue labels from the batch, the corresponding hierarchical pair and the penalty for hierarchy violation
#         - call loss.backward(), optimizer.step() and add calculated loss to total_train_loss, report avg loss
#     - Inside for loop (validation):
#         - model.eval(), total_val_loss init, initialize empty predictions and labels lists
#         - with torch.no_grad(), for loop calculating losses and appending predictions and labels to previous lists
#         - avg loss reporting
#         - Calculate metrics on validation set and report (help was needed for calculations)
#         - save best_model, checkpoints every 50 epochs
# 6. Testing:
#     - load best model, put model in eval mode
#     - get ROCAUC on all tissues and ROCAUC on 107 leaf tissues (comparator)

# %%
protein_embedding_dim = 256
num_heads = 16
gat_hidden_channels = 256
gat_output_channels = 256
tissue_address_dim = global_tissue_address.shape[1]
mlp_hidden_channels = 1024
dropout_rate = 0.3

model = LateFusionGAT(
    num_proteins=num_unique_proteins,
    protein_embedding_dim=protein_embedding_dim,
    num_heads=num_heads,
    gat_hidden_channels=gat_hidden_channels,
    gat_output_channels=gat_output_channels,
    tissue_address_dim=tissue_address_dim,
    mlp_hidden_channels=mlp_hidden_channels,
    num_tissues=num_tissues, # Use the consistent num_tissues from Node2Vec setup
    global_tissue_address_tensor=global_tissue_address,
    dropout_rate=dropout_rate
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# --- Training and Validation Loop ---
num_epochs = 1000
patience = 50
early_stop_counter = 0
best_val_loss = float('inf')

history_train_loss = []
history_val_loss = []

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    for i, batch in enumerate(train_loader):
        batch = batch.to(device)
        optimizer.zero_grad()
        
        predictions = model(batch)
        loss = custom_loss(predictions, batch.edge_label, hierarchical_pairs.to(device), lambda_penalty=0.1)
        
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()
            
    avg_train_loss = total_train_loss / len(train_loader)
    history_train_loss.append(avg_train_loss)
    print(f"\nEpoch {epoch+1} finished. Avg Train Loss: {avg_train_loss:.4f}")

    # --- Validation Loop ---
    model.eval()
    total_val_loss = 0
    all_val_preds = []
    all_val_labels = []

    with torch.no_grad():
        for i, batch in enumerate(val_loader):
            batch = batch.to(device)
            predictions = model(batch)
            loss = custom_loss(predictions, batch.edge_label, hierarchical_pairs.to(device), lambda_penalty=0.1)
            total_val_loss += loss.item()

            all_val_preds.append(predictions.cpu())
            all_val_labels.append(batch.edge_label.cpu())
    avg_val_loss = total_val_loss / len(val_loader)
    history_val_loss.append(avg_val_loss)
    print(f"  Validation Loss: {avg_val_loss:.4f}")

    # Concatenate all predictions and labels for metric calculation
    all_val_preds = torch.cat(all_val_preds, dim=0)
    all_val_labels = torch.cat(all_val_labels, dim=0)

    #Validation metrics -> ROCAUC, ROCPRC and Macro-F1 (non-weighted avg F1-scores of all the tissues)
    val_roc_auc = []
    y_true_np = all_val_labels.numpy(); y_pred_np = all_val_preds.numpy()
    # Compute metrics on CPU with NumPy for stability
    y_true_np = all_val_labels.numpy()
    y_pred_np = all_val_preds.numpy()
    val_roc_prc = []
    val_f1 = []

    for j in range(num_tissues): #I needed help with this to properly calculate the metrics
        # Evaluate only if both positive and negative classes are present
        if y_true_np[:, j].sum() > 0 and (1.0 - y_true_np[:, j]).sum() > 0:
            try:
                val_roc_auc.append(roc_auc_score(y_true_np[:, j], y_pred_np[:, j]))
                val_roc_prc.append(average_precision_score(y_true_np[:, j], y_pred_np[:, j]))
                # For F1, you typically need to binarize predictions. Let's use a common threshold of 0.5 for now.
                val_f1.append(f1_score(y_true_np[:, j], (y_pred_np[:, j] > 0.5).astype(float)))
            except ValueError:
                pass
    
    avg_val_roc_auc = sum(val_roc_auc) / len(val_roc_auc) if val_roc_auc else 0
    avg_val_roc_prc = sum(val_roc_prc) / len(val_roc_prc) if val_roc_prc else 0
    avg_val_f1 = sum(val_f1) / len(val_f1) if val_f1 else 0

    print(f"  Validation ROCAUC: {avg_val_roc_auc:.4f}, ROCPRC: {avg_val_roc_prc:.4f}, Macro-F1: {avg_val_f1:.4f}")

    # Save best model based on validation loss or ROCAUC
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        early_stop_counter = 0 # Reset counter
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': best_val_loss
        }, 'best_model.pt')
        print("  >>> New best model checkpoint saved!")
    else:
        early_stop_counter += 1
        
    # Regular checkpointing every 50 epochs
    if (epoch + 1) % 50 == 0:
        os.makedirs('checkpoints', exist_ok=True)
        checkpoint_path = f'checkpoints/checkpoint_epoch_{epoch+1}.pt'
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': avg_val_loss
        }, checkpoint_path)
        print(f"  Saved epoch checkpoint to {checkpoint_path}")
    if early_stop_counter >= patience:
        print(f'Early stopping triggered after {epoch+1} epochs.')
        break


# --- Test Loop (After training is complete) ---
print("\n--- Starting Final Test Evaluation ---")
checkpoint = torch.load('best_model.pt', weights_only=True)
model.load_state_dict(checkpoint['model_state_dict']) # Load the best model
model.eval()
total_test_loss = 0
all_test_preds = []
all_test_labels = []

with torch.no_grad():
    for i, batch in enumerate(test_loader):
        batch = batch.to(device)
        predictions = model(batch)
        loss = custom_loss(predictions, batch.edge_label, hierarchical_pairs.to(device), lambda_penalty=0.1)
        total_test_loss += loss.item()

        all_test_preds.append(predictions.cpu())
        all_test_labels.append(batch.edge_label.cpu())
        
        # --- Memory Management ---
avg_test_loss = total_test_loss / len(test_loader)
print(f"  Test Loss: {avg_test_loss:.4f}")

all_test_preds = torch.cat(all_test_preds, dim=0)
all_test_labels = torch.cat(all_test_labels, dim=0)

# --- Final Test Metrics ---
y_true_test = all_test_labels.numpy()
y_pred_test = all_test_preds.numpy()

# Metrics for ALL tissues
all_roc_auc = [roc_auc_score(y_true_test[:, j], y_pred_test[:, j]) for j in range(num_tissues) if y_true_test[:, j].sum() > 0 and (1.0 - y_true_test[:, j]).sum() > 0]
print(f'  Final Test ROCAUC (All 144 Tissues): {sum(all_roc_auc)/len(all_roc_auc):.4f}')

# Metrics for LEAF tissues (Goal target)
# Select only the predictions and labels for the 107 leaf nodes
test_preds_leaf = all_test_preds[:, leaf_node_indices].numpy()
test_labels_leaf = all_test_labels[:, leaf_node_indices].numpy()
test_roc_auc = []
for j in range(len(leaf_node_indices)):
    if test_labels_leaf[:, j].sum() > 0 and (1.0 - test_labels_leaf[:, j]).sum() > 0:
        try:
            test_roc_auc.append(roc_auc_score(test_labels_leaf[:, j], test_preds_leaf[:, j]))
        except: pass
avg_test_roc_auc = sum(test_roc_auc) / len(test_roc_auc) if test_roc_auc else 0
print(f'  Final Test ROCAUC (107 Leaf Tissues): {avg_test_roc_auc:.4f}')
target_roc_auc = 0.756
if avg_test_roc_auc > target_roc_auc:
    print(f"  Goal Achieved! Test ROCAUC ({avg_test_roc_auc:.4f}) exceeded target ({target_roc_auc:.4f}).")
else:
    print(f"  Goal Not Met. Test ROCAUC ({avg_test_roc_auc:.4f}) is below target ({target_roc_auc:.4f}).")
# Out:
# Epoch 1 finished. Avg Train Loss: 0.4047
#   Validation Loss: 0.3708
#   Validation ROCAUC: 0.6281, ROCPRC: 0.4546, Macro-F1: 0.2778
#   >>> New best model checkpoint saved!
#
# Epoch 2 finished. Avg Train Loss: 0.3699
#   Validation Loss: 0.3574
#   Validation ROCAUC: 0.6752, ROCPRC: 0.4956, Macro-F1: 0.3149
#   >>> New best model checkpoint saved!
#
# Epoch 3 finished. Avg Train Loss: 0.3597
#   Validation Loss: 0.3466
#   Validation ROCAUC: 0.7070, ROCPRC: 0.5214, Macro-F1: 0.3527
#   >>> New best model checkpoint saved!
#
# Epoch 4 finished. Avg Train Loss: 0.3498
#   Validation Loss: 0.3408
#   Validation ROCAUC: 0.7167, ROCPRC: 0.5297, Macro-F1: 0.3658
#   >>> New best model checkpoint saved!
#
# Epoch 5 finished. Avg Train Loss: 0.3451
#   Validation Loss: 0.3358
#   Validation ROCAUC: 0.7366, ROCPRC: 0.5478, Macro-F1: 0.3932
#   >>> New best model checkpoint saved!
#
# Epoch 6 finished. Avg Train Loss: 0.3409
#   Validation Loss: 0.3346
#   Validation ROCAUC: 0.7494, ROCPRC: 0.5609, Macro-F1: 0.4202
#   >>> New best model checkpoint saved!
#
# Epoch 7 finished. Avg Train Loss: 0.3390
#   Validation Loss: 0.3244
#   Validation ROCAUC: 0.7597, ROCPRC: 0.5723, Macro-F1: 0.4008
#   >>> New best model checkpoint saved!
#
# Epoch 8 finished. Avg Train Loss: 0.3334
#   Validation Loss: 0.3207
#   Validation ROCAUC: 0.7747, ROCPRC: 0.5971, Macro-F1: 0.4656
#   >>> New best model checkpoint saved!
#
# Epoch 9 finished. Avg Train Loss: 0.3317
#   Validation Loss: 0.3165
#   Validation ROCAUC: 0.7779, ROCPRC: 0.6032, Macro-F1: 0.4010
#   >>> New best model checkpoint saved!
#
# Epoch 10 finished. Avg Train Loss: 0.3293
#   Validation Loss: 0.3164
#   Validation ROCAUC: 0.7777, ROCPRC: 0.5988, Macro-F1: 0.4284
#   >>> New best model checkpoint saved!
#
# Epoch 11 finished. Avg Train Loss: 0.3255
#   Validation Loss: 0.3156
#   Validation ROCAUC: 0.7771, ROCPRC: 0.5924, Macro-F1: 0.4635
#   >>> New best model checkpoint saved!
#
# Epoch 12 finished. Avg Train Loss: 0.3254
#   Validation Loss: 0.3081
#   Validation ROCAUC: 0.7927, ROCPRC: 0.6147, Macro-F1: 0.4461
#   >>> New best model checkpoint saved!
#
# Epoch 13 finished. Avg Train Loss: 0.3222
#   Validation Loss: 0.3029
#   Validation ROCAUC: 0.8013, ROCPRC: 0.6236, Macro-F1: 0.4969
#   >>> New best model checkpoint saved!
#
# Epoch 14 finished. Avg Train Loss: 0.3198
#   Validation Loss: 0.3055
#   Validation ROCAUC: 0.8032, ROCPRC: 0.6286, Macro-F1: 0.4849
#
# Epoch 15 finished. Avg Train Loss: 0.3179
#   Validation Loss: 0.3034
#   Validation ROCAUC: 0.8060, ROCPRC: 0.6299, Macro-F1: 0.4871
#
# Epoch 16 finished. Avg Train Loss: 0.3156
#   Validation Loss: 0.3040
#   Validation ROCAUC: 0.8034, ROCPRC: 0.6295, Macro-F1: 0.5045
#
# Epoch 17 finished. Avg Train Loss: 0.3140
#   Validation Loss: 0.2971
#   Validation ROCAUC: 0.8124, ROCPRC: 0.6413, Macro-F1: 0.5024
#   >>> New best model checkpoint saved!
#
# Epoch 18 finished. Avg Train Loss: 0.3120
#   Validation Loss: 0.2981
#   Validation ROCAUC: 0.8102, ROCPRC: 0.6391, Macro-F1: 0.4787
#
# Epoch 19 finished. Avg Train Loss: 0.3121
#   Validation Loss: 0.2941
#   Validation ROCAUC: 0.8183, ROCPRC: 0.6490, Macro-F1: 0.4952
#   >>> New best model checkpoint saved!
#
# Epoch 20 finished. Avg Train Loss: 0.3084
#   Validation Loss: 0.2944
#   Validation ROCAUC: 0.8172, ROCPRC: 0.6506, Macro-F1: 0.5073
#
# Epoch 21 finished. Avg Train Loss: 0.3074
#   Validation Loss: 0.2927
#   Validation ROCAUC: 0.8237, ROCPRC: 0.6569, Macro-F1: 0.5073
#   >>> New best model checkpoint saved!
#
# Epoch 22 finished. Avg Train Loss: 0.3071
#   Validation Loss: 0.2882
#   Validation ROCAUC: 0.8257, ROCPRC: 0.6618, Macro-F1: 0.5139
#   >>> New best model checkpoint saved!
#
# Epoch 23 finished. Avg Train Loss: 0.3031
#   Validation Loss: 0.2936
#   Validation ROCAUC: 0.8198, ROCPRC: 0.6507, Macro-F1: 0.4801
#
# Epoch 24 finished. Avg Train Loss: 0.3058
#   Validation Loss: 0.2841
#   Validation ROCAUC: 0.8306, ROCPRC: 0.6660, Macro-F1: 0.5694
#   >>> New best model checkpoint saved!
#
# Epoch 25 finished. Avg Train Loss: 0.3024
#   Validation Loss: 0.2828
#   Validation ROCAUC: 0.8339, ROCPRC: 0.6674, Macro-F1: 0.5689
#   >>> New best model checkpoint saved!
#
# Epoch 26 finished. Avg Train Loss: 0.3047
#   Validation Loss: 0.2896
#   Validation ROCAUC: 0.8307, ROCPRC: 0.6678, Macro-F1: 0.5115
#
# Epoch 27 finished. Avg Train Loss: 0.3015
#   Validation Loss: 0.2824
#   Validation ROCAUC: 0.8354, ROCPRC: 0.6770, Macro-F1: 0.5472
#   >>> New best model checkpoint saved!
#
# Epoch 28 finished. Avg Train Loss: 0.3010
#   Validation Loss: 0.2833
#   Validation ROCAUC: 0.8334, ROCPRC: 0.6703, Macro-F1: 0.5570
#
# Epoch 29 finished. Avg Train Loss: 0.2997
#   Validation Loss: 0.2792
#   Validation ROCAUC: 0.8402, ROCPRC: 0.6856, Macro-F1: 0.5487
#   >>> New best model checkpoint saved!
#
# Epoch 30 finished. Avg Train Loss: 0.2983
#   Validation Loss: 0.2847
#   Validation ROCAUC: 0.8393, ROCPRC: 0.6869, Macro-F1: 0.5785
#
# Epoch 31 finished. Avg Train Loss: 0.2982
#   Validation Loss: 0.2788
#   Validation ROCAUC: 0.8401, ROCPRC: 0.6849, Macro-F1: 0.5497
#   >>> New best model checkpoint saved!
#
# Epoch 32 finished. Avg Train Loss: 0.2982
#   Validation Loss: 0.2838
#   Validation ROCAUC: 0.8357, ROCPRC: 0.6763, Macro-F1: 0.5797
#
# Epoch 33 finished. Avg Train Loss: 0.2960
#   Validation Loss: 0.2768
#   Validation ROCAUC: 0.8444, ROCPRC: 0.6914, Macro-F1: 0.6168
#   >>> New best model checkpoint saved!
#
# Epoch 34 finished. Avg Train Loss: 0.2942
#   Validation Loss: 0.2740
#   Validation ROCAUC: 0.8486, ROCPRC: 0.6975, Macro-F1: 0.5504
#   >>> New best model checkpoint saved!
#
# Epoch 35 finished. Avg Train Loss: 0.2917
#   Validation Loss: 0.2730
#   Validation ROCAUC: 0.8522, ROCPRC: 0.7014, Macro-F1: 0.5725
#   >>> New best model checkpoint saved!
#
# Epoch 36 finished. Avg Train Loss: 0.2921
#   Validation Loss: 0.2673
#   Validation ROCAUC: 0.8579, ROCPRC: 0.7048, Macro-F1: 0.5888
#   >>> New best model checkpoint saved!
#
# Epoch 37 finished. Avg Train Loss: 0.2908
#   Validation Loss: 0.2719
#   Validation ROCAUC: 0.8528, ROCPRC: 0.7048, Macro-F1: 0.5543
#
# Epoch 38 finished. Avg Train Loss: 0.2912
#   Validation Loss: 0.2703
#   Validation ROCAUC: 0.8531, ROCPRC: 0.7031, Macro-F1: 0.5824
#
# Epoch 39 finished. Avg Train Loss: 0.2909
#   Validation Loss: 0.2697
#   Validation ROCAUC: 0.8555, ROCPRC: 0.7104, Macro-F1: 0.5713
#
# Epoch 40 finished. Avg Train Loss: 0.2894
#   Validation Loss: 0.2668
#   Validation ROCAUC: 0.8582, ROCPRC: 0.7113, Macro-F1: 0.6094
#   >>> New best model checkpoint saved!
#
# Epoch 41 finished. Avg Train Loss: 0.2877
#   Validation Loss: 0.2668
#   Validation ROCAUC: 0.8601, ROCPRC: 0.7144, Macro-F1: 0.6064
#   >>> New best model checkpoint saved!
#
# Epoch 42 finished. Avg Train Loss: 0.2856
#   Validation Loss: 0.2644
#   Validation ROCAUC: 0.8591, ROCPRC: 0.7083, Macro-F1: 0.5917
#   >>> New best model checkpoint saved!
#
# Epoch 43 finished. Avg Train Loss: 0.2852
#   Validation Loss: 0.2640
#   Validation ROCAUC: 0.8628, ROCPRC: 0.7124, Macro-F1: 0.5909
#   >>> New best model checkpoint saved!
#
# Epoch 44 finished. Avg Train Loss: 0.2847
#   Validation Loss: 0.2691
#   Validation ROCAUC: 0.8600, ROCPRC: 0.7137, Macro-F1: 0.5976
#
# Epoch 45 finished. Avg Train Loss: 0.2857
#   Validation Loss: 0.2669
#   Validation ROCAUC: 0.8603, ROCPRC: 0.7164, Macro-F1: 0.5747
#
# Epoch 46 finished. Avg Train Loss: 0.2824
#   Validation Loss: 0.2611
#   Validation ROCAUC: 0.8649, ROCPRC: 0.7180, Macro-F1: 0.5698
#   >>> New best model checkpoint saved!
#
# Epoch 47 finished. Avg Train Loss: 0.2822
#   Validation Loss: 0.2611
#   Validation ROCAUC: 0.8652, ROCPRC: 0.7225, Macro-F1: 0.6118
#
# Epoch 48 finished. Avg Train Loss: 0.2834
#   Validation Loss: 0.2608
#   Validation ROCAUC: 0.8664, ROCPRC: 0.7183, Macro-F1: 0.6231
#   >>> New best model checkpoint saved!
#
# Epoch 49 finished. Avg Train Loss: 0.2838
#   Validation Loss: 0.2598
#   Validation ROCAUC: 0.8684, ROCPRC: 0.7259, Macro-F1: 0.5912
#   >>> New best model checkpoint saved!
#
# Epoch 50 finished. Avg Train Loss: 0.2805
#   Validation Loss: 0.2555
#   Validation ROCAUC: 0.8725, ROCPRC: 0.7313, Macro-F1: 0.6109
#   >>> New best model checkpoint saved!
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_50.pt
#
# Epoch 51 finished. Avg Train Loss: 0.2794
#   Validation Loss: 0.2628
#   Validation ROCAUC: 0.8687, ROCPRC: 0.7202, Macro-F1: 0.5417
#
# Epoch 52 finished. Avg Train Loss: 0.2809
#   Validation Loss: 0.2636
#   Validation ROCAUC: 0.8601, ROCPRC: 0.7106, Macro-F1: 0.5998
#
# Epoch 53 finished. Avg Train Loss: 0.2792
#   Validation Loss: 0.2562
#   Validation ROCAUC: 0.8732, ROCPRC: 0.7321, Macro-F1: 0.6135
#
# Epoch 54 finished. Avg Train Loss: 0.2763
#   Validation Loss: 0.2563
#   Validation ROCAUC: 0.8737, ROCPRC: 0.7311, Macro-F1: 0.5808
#
# Epoch 55 finished. Avg Train Loss: 0.2744
#   Validation Loss: 0.2581
#   Validation ROCAUC: 0.8678, ROCPRC: 0.7231, Macro-F1: 0.6030
#
# Epoch 56 finished. Avg Train Loss: 0.2732
#   Validation Loss: 0.2540
#   Validation ROCAUC: 0.8775, ROCPRC: 0.7391, Macro-F1: 0.6196
#   >>> New best model checkpoint saved!
#
# Epoch 57 finished. Avg Train Loss: 0.2739
#   Validation Loss: 0.2544
#   Validation ROCAUC: 0.8739, ROCPRC: 0.7349, Macro-F1: 0.5968
#
# Epoch 58 finished. Avg Train Loss: 0.2742
#   Validation Loss: 0.2516
#   Validation ROCAUC: 0.8791, ROCPRC: 0.7394, Macro-F1: 0.6136
#   >>> New best model checkpoint saved!
#
# Epoch 59 finished. Avg Train Loss: 0.2733
#   Validation Loss: 0.2469
#   Validation ROCAUC: 0.8815, ROCPRC: 0.7439, Macro-F1: 0.6092
#   >>> New best model checkpoint saved!
#
# Epoch 60 finished. Avg Train Loss: 0.2765
#   Validation Loss: 0.2569
#   Validation ROCAUC: 0.8731, ROCPRC: 0.7293, Macro-F1: 0.5915
#
# Epoch 61 finished. Avg Train Loss: 0.2738
#   Validation Loss: 0.2538
#   Validation ROCAUC: 0.8761, ROCPRC: 0.7340, Macro-F1: 0.6101
#
# Epoch 62 finished. Avg Train Loss: 0.2745
#   Validation Loss: 0.2558
#   Validation ROCAUC: 0.8739, ROCPRC: 0.7318, Macro-F1: 0.5989
#
# Epoch 63 finished. Avg Train Loss: 0.2728
#   Validation Loss: 0.2521
#   Validation ROCAUC: 0.8765, ROCPRC: 0.7368, Macro-F1: 0.6094
#
# Epoch 64 finished. Avg Train Loss: 0.2735
#   Validation Loss: 0.2492
#   Validation ROCAUC: 0.8816, ROCPRC: 0.7460, Macro-F1: 0.5994
#
# Epoch 65 finished. Avg Train Loss: 0.2704
#   Validation Loss: 0.2535
#   Validation ROCAUC: 0.8764, ROCPRC: 0.7356, Macro-F1: 0.6024
#
# Epoch 66 finished. Avg Train Loss: 0.2693
#   Validation Loss: 0.2449
#   Validation ROCAUC: 0.8837, ROCPRC: 0.7423, Macro-F1: 0.6211
#   >>> New best model checkpoint saved!
#
# Epoch 67 finished. Avg Train Loss: 0.2714
#   Validation Loss: 0.2491
#   Validation ROCAUC: 0.8813, ROCPRC: 0.7421, Macro-F1: 0.6383
#
# Epoch 68 finished. Avg Train Loss: 0.2721
#   Validation Loss: 0.2474
#   Validation ROCAUC: 0.8831, ROCPRC: 0.7425, Macro-F1: 0.5823
#
# Epoch 69 finished. Avg Train Loss: 0.2692
#   Validation Loss: 0.2485
#   Validation ROCAUC: 0.8812, ROCPRC: 0.7435, Macro-F1: 0.6480
#
# Epoch 70 finished. Avg Train Loss: 0.2683
#   Validation Loss: 0.2488
#   Validation ROCAUC: 0.8826, ROCPRC: 0.7455, Macro-F1: 0.6273
#
# Epoch 71 finished. Avg Train Loss: 0.2683
#   Validation Loss: 0.2467
#   Validation ROCAUC: 0.8821, ROCPRC: 0.7465, Macro-F1: 0.6394
#
# Epoch 72 finished. Avg Train Loss: 0.2670
#   Validation Loss: 0.2418
#   Validation ROCAUC: 0.8885, ROCPRC: 0.7517, Macro-F1: 0.6261
#   >>> New best model checkpoint saved!
#
# Epoch 73 finished. Avg Train Loss: 0.2675
#   Validation Loss: 0.2416
#   Validation ROCAUC: 0.8891, ROCPRC: 0.7527, Macro-F1: 0.6407
#   >>> New best model checkpoint saved!
#
# Epoch 74 finished. Avg Train Loss: 0.2748
#   Validation Loss: 0.2513
#   Validation ROCAUC: 0.8798, ROCPRC: 0.7377, Macro-F1: 0.5927
#
# Epoch 75 finished. Avg Train Loss: 0.2708
#   Validation Loss: 0.2440
#   Validation ROCAUC: 0.8858, ROCPRC: 0.7452, Macro-F1: 0.6480
#
# Epoch 76 finished. Avg Train Loss: 0.2664
#   Validation Loss: 0.2471
#   Validation ROCAUC: 0.8853, ROCPRC: 0.7506, Macro-F1: 0.6508
#
# Epoch 77 finished. Avg Train Loss: 0.2649
#   Validation Loss: 0.2400
#   Validation ROCAUC: 0.8911, ROCPRC: 0.7537, Macro-F1: 0.6235
#   >>> New best model checkpoint saved!
#
# Epoch 78 finished. Avg Train Loss: 0.2634
#   Validation Loss: 0.2375
#   Validation ROCAUC: 0.8928, ROCPRC: 0.7591, Macro-F1: 0.6369
#   >>> New best model checkpoint saved!
#
# Epoch 79 finished. Avg Train Loss: 0.2625
#   Validation Loss: 0.2366
#   Validation ROCAUC: 0.8937, ROCPRC: 0.7590, Macro-F1: 0.6415
#   >>> New best model checkpoint saved!
#
# Epoch 80 finished. Avg Train Loss: 0.2617
#   Validation Loss: 0.2427
#   Validation ROCAUC: 0.8891, ROCPRC: 0.7513, Macro-F1: 0.6594
#
# Epoch 81 finished. Avg Train Loss: 0.2635
#   Validation Loss: 0.2396
#   Validation ROCAUC: 0.8921, ROCPRC: 0.7628, Macro-F1: 0.6320
#
# Epoch 82 finished. Avg Train Loss: 0.2624
#   Validation Loss: 0.2370
#   Validation ROCAUC: 0.8927, ROCPRC: 0.7578, Macro-F1: 0.6538
#
# Epoch 83 finished. Avg Train Loss: 0.2618
#   Validation Loss: 0.2414
#   Validation ROCAUC: 0.8912, ROCPRC: 0.7566, Macro-F1: 0.6089
#
# Epoch 84 finished. Avg Train Loss: 0.2605
#   Validation Loss: 0.2347
#   Validation ROCAUC: 0.8956, ROCPRC: 0.7638, Macro-F1: 0.6448
#   >>> New best model checkpoint saved!
#
# Epoch 85 finished. Avg Train Loss: 0.2591
#   Validation Loss: 0.2362
#   Validation ROCAUC: 0.8946, ROCPRC: 0.7634, Macro-F1: 0.6644
#
# Epoch 86 finished. Avg Train Loss: 0.2587
#   Validation Loss: 0.2307
#   Validation ROCAUC: 0.8985, ROCPRC: 0.7660, Macro-F1: 0.6550
#   >>> New best model checkpoint saved!
#
# Epoch 87 finished. Avg Train Loss: 0.2585
#   Validation Loss: 0.2388
#   Validation ROCAUC: 0.8954, ROCPRC: 0.7625, Macro-F1: 0.6725
#
# Epoch 88 finished. Avg Train Loss: 0.2601
#   Validation Loss: 0.2314
#   Validation ROCAUC: 0.8991, ROCPRC: 0.7644, Macro-F1: 0.6685
#
# Epoch 89 finished. Avg Train Loss: 0.2572
#   Validation Loss: 0.2343
#   Validation ROCAUC: 0.8965, ROCPRC: 0.7647, Macro-F1: 0.6236
#
# Epoch 90 finished. Avg Train Loss: 0.2565
#   Validation Loss: 0.2286
#   Validation ROCAUC: 0.9011, ROCPRC: 0.7706, Macro-F1: 0.6689
#   >>> New best model checkpoint saved!
#
# Epoch 91 finished. Avg Train Loss: 0.2561
#   Validation Loss: 0.2312
#   Validation ROCAUC: 0.8987, ROCPRC: 0.7683, Macro-F1: 0.6383
#
# Epoch 92 finished. Avg Train Loss: 0.2538
#   Validation Loss: 0.2290
#   Validation ROCAUC: 0.9009, ROCPRC: 0.7719, Macro-F1: 0.6647
#
# Epoch 93 finished. Avg Train Loss: 0.2554
#   Validation Loss: 0.2297
#   Validation ROCAUC: 0.8999, ROCPRC: 0.7694, Macro-F1: 0.6671
#
# Epoch 94 finished. Avg Train Loss: 0.2535
#   Validation Loss: 0.2312
#   Validation ROCAUC: 0.8977, ROCPRC: 0.7693, Macro-F1: 0.6572
#
# Epoch 95 finished. Avg Train Loss: 0.2564
#   Validation Loss: 0.2312
#   Validation ROCAUC: 0.9027, ROCPRC: 0.7712, Macro-F1: 0.6684
#
# Epoch 96 finished. Avg Train Loss: 0.2541
#   Validation Loss: 0.2242
#   Validation ROCAUC: 0.9060, ROCPRC: 0.7785, Macro-F1: 0.6417
#   >>> New best model checkpoint saved!
#
# Epoch 97 finished. Avg Train Loss: 0.2530
#   Validation Loss: 0.2273
#   Validation ROCAUC: 0.9027, ROCPRC: 0.7789, Macro-F1: 0.6669
#
# Epoch 98 finished. Avg Train Loss: 0.2536
#   Validation Loss: 0.2297
#   Validation ROCAUC: 0.8989, ROCPRC: 0.7680, Macro-F1: 0.6559
#
# Epoch 99 finished. Avg Train Loss: 0.2552
#   Validation Loss: 0.2271
#   Validation ROCAUC: 0.9029, ROCPRC: 0.7723, Macro-F1: 0.6750
#
# Epoch 100 finished. Avg Train Loss: 0.2537
#   Validation Loss: 0.2314
#   Validation ROCAUC: 0.8990, ROCPRC: 0.7715, Macro-F1: 0.6451
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_100.pt
#
# Epoch 101 finished. Avg Train Loss: 0.2540
#   Validation Loss: 0.2243
#   Validation ROCAUC: 0.9062, ROCPRC: 0.7795, Macro-F1: 0.6495
#
# Epoch 102 finished. Avg Train Loss: 0.2505
#   Validation Loss: 0.2231
#   Validation ROCAUC: 0.9076, ROCPRC: 0.7809, Macro-F1: 0.6716
#   >>> New best model checkpoint saved!
#
# Epoch 103 finished. Avg Train Loss: 0.2514
#   Validation Loss: 0.2243
#   Validation ROCAUC: 0.9055, ROCPRC: 0.7780, Macro-F1: 0.6574
#
# Epoch 104 finished. Avg Train Loss: 0.2512
#   Validation Loss: 0.2248
#   Validation ROCAUC: 0.9048, ROCPRC: 0.7774, Macro-F1: 0.6436
#
# Epoch 105 finished. Avg Train Loss: 0.2508
#   Validation Loss: 0.2210
#   Validation ROCAUC: 0.9089, ROCPRC: 0.7863, Macro-F1: 0.6580
#   >>> New best model checkpoint saved!
#
# Epoch 106 finished. Avg Train Loss: 0.2496
#   Validation Loss: 0.2245
#   Validation ROCAUC: 0.9058, ROCPRC: 0.7780, Macro-F1: 0.6466
#
# Epoch 107 finished. Avg Train Loss: 0.2489
#   Validation Loss: 0.2235
#   Validation ROCAUC: 0.9082, ROCPRC: 0.7793, Macro-F1: 0.6831
#
# Epoch 108 finished. Avg Train Loss: 0.2495
#   Validation Loss: 0.2208
#   Validation ROCAUC: 0.9095, ROCPRC: 0.7849, Macro-F1: 0.6529
#   >>> New best model checkpoint saved!
#
# Epoch 109 finished. Avg Train Loss: 0.2484
#   Validation Loss: 0.2231
#   Validation ROCAUC: 0.9068, ROCPRC: 0.7779, Macro-F1: 0.6633
#
# Epoch 110 finished. Avg Train Loss: 0.2484
#   Validation Loss: 0.2191
#   Validation ROCAUC: 0.9109, ROCPRC: 0.7844, Macro-F1: 0.6574
#   >>> New best model checkpoint saved!
#
# Epoch 111 finished. Avg Train Loss: 0.2480
#   Validation Loss: 0.2207
#   Validation ROCAUC: 0.9080, ROCPRC: 0.7813, Macro-F1: 0.6779
#
# Epoch 112 finished. Avg Train Loss: 0.2474
#   Validation Loss: 0.2187
#   Validation ROCAUC: 0.9121, ROCPRC: 0.7874, Macro-F1: 0.6722
#   >>> New best model checkpoint saved!
#
# Epoch 113 finished. Avg Train Loss: 0.2464
#   Validation Loss: 0.2222
#   Validation ROCAUC: 0.9091, ROCPRC: 0.7826, Macro-F1: 0.6599
#
# Epoch 114 finished. Avg Train Loss: 0.2475
#   Validation Loss: 0.2227
#   Validation ROCAUC: 0.9084, ROCPRC: 0.7803, Macro-F1: 0.6411
#
# Epoch 115 finished. Avg Train Loss: 0.2476
#   Validation Loss: 0.2212
#   Validation ROCAUC: 0.9109, ROCPRC: 0.7834, Macro-F1: 0.6911
#
# Epoch 116 finished. Avg Train Loss: 0.2469
#   Validation Loss: 0.2157
#   Validation ROCAUC: 0.9136, ROCPRC: 0.7906, Macro-F1: 0.6705
#   >>> New best model checkpoint saved!
#
# Epoch 117 finished. Avg Train Loss: 0.2455
#   Validation Loss: 0.2176
#   Validation ROCAUC: 0.9134, ROCPRC: 0.7890, Macro-F1: 0.6855
#
# Epoch 118 finished. Avg Train Loss: 0.2441
#   Validation Loss: 0.2169
#   Validation ROCAUC: 0.9142, ROCPRC: 0.7924, Macro-F1: 0.6666
#
# Epoch 119 finished. Avg Train Loss: 0.2436
#   Validation Loss: 0.2166
#   Validation ROCAUC: 0.9132, ROCPRC: 0.7884, Macro-F1: 0.6644
#
# Epoch 120 finished. Avg Train Loss: 0.2468
#   Validation Loss: 0.2204
#   Validation ROCAUC: 0.9114, ROCPRC: 0.7864, Macro-F1: 0.6771
#
# Epoch 121 finished. Avg Train Loss: 0.2439
#   Validation Loss: 0.2132
#   Validation ROCAUC: 0.9154, ROCPRC: 0.7951, Macro-F1: 0.6912
#   >>> New best model checkpoint saved!
#
# Epoch 122 finished. Avg Train Loss: 0.2427
#   Validation Loss: 0.2146
#   Validation ROCAUC: 0.9147, ROCPRC: 0.7905, Macro-F1: 0.6935
#
# Epoch 123 finished. Avg Train Loss: 0.2420
#   Validation Loss: 0.2136
#   Validation ROCAUC: 0.9157, ROCPRC: 0.7958, Macro-F1: 0.6944
#
# Epoch 124 finished. Avg Train Loss: 0.2414
#   Validation Loss: 0.2132
#   Validation ROCAUC: 0.9171, ROCPRC: 0.7962, Macro-F1: 0.6691
#
# Epoch 125 finished. Avg Train Loss: 0.2434
#   Validation Loss: 0.2134
#   Validation ROCAUC: 0.9135, ROCPRC: 0.7908, Macro-F1: 0.6859
#
# Epoch 126 finished. Avg Train Loss: 0.2449
#   Validation Loss: 0.2140
#   Validation ROCAUC: 0.9140, ROCPRC: 0.7885, Macro-F1: 0.6714
#
# Epoch 127 finished. Avg Train Loss: 0.2429
#   Validation Loss: 0.2163
#   Validation ROCAUC: 0.9125, ROCPRC: 0.7894, Macro-F1: 0.6847
#
# Epoch 128 finished. Avg Train Loss: 0.2420
#   Validation Loss: 0.2169
#   Validation ROCAUC: 0.9123, ROCPRC: 0.7907, Macro-F1: 0.6746
#
# Epoch 129 finished. Avg Train Loss: 0.2423
#   Validation Loss: 0.2155
#   Validation ROCAUC: 0.9132, ROCPRC: 0.7878, Macro-F1: 0.6568
#
# Epoch 130 finished. Avg Train Loss: 0.2421
#   Validation Loss: 0.2126
#   Validation ROCAUC: 0.9165, ROCPRC: 0.7933, Macro-F1: 0.6743
#   >>> New best model checkpoint saved!
#
# Epoch 131 finished. Avg Train Loss: 0.2416
#   Validation Loss: 0.2137
#   Validation ROCAUC: 0.9162, ROCPRC: 0.7950, Macro-F1: 0.6939
#
# Epoch 132 finished. Avg Train Loss: 0.2388
#   Validation Loss: 0.2103
#   Validation ROCAUC: 0.9177, ROCPRC: 0.7982, Macro-F1: 0.6849
#   >>> New best model checkpoint saved!
#
# Epoch 133 finished. Avg Train Loss: 0.2379
#   Validation Loss: 0.2105
#   Validation ROCAUC: 0.9183, ROCPRC: 0.7959, Macro-F1: 0.6816
#
# Epoch 134 finished. Avg Train Loss: 0.2369
#   Validation Loss: 0.2089
#   Validation ROCAUC: 0.9198, ROCPRC: 0.7991, Macro-F1: 0.6926
#   >>> New best model checkpoint saved!
#
# Epoch 135 finished. Avg Train Loss: 0.2366
#   Validation Loss: 0.2047
#   Validation ROCAUC: 0.9222, ROCPRC: 0.8022, Macro-F1: 0.7015
#   >>> New best model checkpoint saved!
#
# Epoch 136 finished. Avg Train Loss: 0.2372
#   Validation Loss: 0.2123
#   Validation ROCAUC: 0.9167, ROCPRC: 0.7942, Macro-F1: 0.6992
#
# Epoch 137 finished. Avg Train Loss: 0.2386
#   Validation Loss: 0.2114
#   Validation ROCAUC: 0.9194, ROCPRC: 0.7982, Macro-F1: 0.7075
#
# Epoch 138 finished. Avg Train Loss: 0.2390
#   Validation Loss: 0.2083
#   Validation ROCAUC: 0.9204, ROCPRC: 0.8014, Macro-F1: 0.6794
#
# Epoch 139 finished. Avg Train Loss: 0.2382
#   Validation Loss: 0.2219
#   Validation ROCAUC: 0.9069, ROCPRC: 0.7775, Macro-F1: 0.6795
#
# Epoch 140 finished. Avg Train Loss: 0.2452
#   Validation Loss: 0.2114
#   Validation ROCAUC: 0.9171, ROCPRC: 0.7938, Macro-F1: 0.6788
#
# Epoch 141 finished. Avg Train Loss: 0.2381
#   Validation Loss: 0.2092
#   Validation ROCAUC: 0.9191, ROCPRC: 0.8001, Macro-F1: 0.6826
#
# Epoch 142 finished. Avg Train Loss: 0.2374
#   Validation Loss: 0.2099
#   Validation ROCAUC: 0.9182, ROCPRC: 0.7960, Macro-F1: 0.6771
#
# Epoch 143 finished. Avg Train Loss: 0.2383
#   Validation Loss: 0.2071
#   Validation ROCAUC: 0.9198, ROCPRC: 0.7968, Macro-F1: 0.7101
#
# Epoch 144 finished. Avg Train Loss: 0.2369
#   Validation Loss: 0.2053
#   Validation ROCAUC: 0.9223, ROCPRC: 0.7999, Macro-F1: 0.6844
#
# Epoch 145 finished. Avg Train Loss: 0.2389
#   Validation Loss: 0.2171
#   Validation ROCAUC: 0.9141, ROCPRC: 0.7900, Macro-F1: 0.6855
#
# Epoch 146 finished. Avg Train Loss: 0.2421
#   Validation Loss: 0.2141
#   Validation ROCAUC: 0.9148, ROCPRC: 0.7891, Macro-F1: 0.6851
#
# Epoch 147 finished. Avg Train Loss: 0.2390
#   Validation Loss: 0.2066
#   Validation ROCAUC: 0.9227, ROCPRC: 0.8032, Macro-F1: 0.6871
#
# Epoch 148 finished. Avg Train Loss: 0.2370
#   Validation Loss: 0.2076
#   Validation ROCAUC: 0.9203, ROCPRC: 0.7999, Macro-F1: 0.6794
#
# Epoch 149 finished. Avg Train Loss: 0.2366
#   Validation Loss: 0.2051
#   Validation ROCAUC: 0.9226, ROCPRC: 0.8022, Macro-F1: 0.7014
#
# Epoch 150 finished. Avg Train Loss: 0.2354
#   Validation Loss: 0.2076
#   Validation ROCAUC: 0.9211, ROCPRC: 0.8029, Macro-F1: 0.7074
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_150.pt
#
# Epoch 151 finished. Avg Train Loss: 0.2368
#   Validation Loss: 0.2055
#   Validation ROCAUC: 0.9244, ROCPRC: 0.8068, Macro-F1: 0.7025
#
# Epoch 152 finished. Avg Train Loss: 0.2316
#   Validation Loss: 0.2039
#   Validation ROCAUC: 0.9234, ROCPRC: 0.8041, Macro-F1: 0.7068
#   >>> New best model checkpoint saved!
#
# Epoch 153 finished. Avg Train Loss: 0.2348
#   Validation Loss: 0.2064
#   Validation ROCAUC: 0.9246, ROCPRC: 0.8101, Macro-F1: 0.6703
#
# Epoch 154 finished. Avg Train Loss: 0.2330
#   Validation Loss: 0.2038
#   Validation ROCAUC: 0.9236, ROCPRC: 0.8038, Macro-F1: 0.6979
#   >>> New best model checkpoint saved!
#
# Epoch 155 finished. Avg Train Loss: 0.2346
#   Validation Loss: 0.2058
#   Validation ROCAUC: 0.9217, ROCPRC: 0.8024, Macro-F1: 0.6910
#
# Epoch 156 finished. Avg Train Loss: 0.2327
#   Validation Loss: 0.2037
#   Validation ROCAUC: 0.9247, ROCPRC: 0.8031, Macro-F1: 0.6763
#   >>> New best model checkpoint saved!
#
# Epoch 157 finished. Avg Train Loss: 0.2314
#   Validation Loss: 0.2031
#   Validation ROCAUC: 0.9250, ROCPRC: 0.8057, Macro-F1: 0.6795
#   >>> New best model checkpoint saved!
#
# Epoch 158 finished. Avg Train Loss: 0.2347
#   Validation Loss: 0.2081
#   Validation ROCAUC: 0.9198, ROCPRC: 0.7957, Macro-F1: 0.6988
#
# Epoch 159 finished. Avg Train Loss: 0.2341
#   Validation Loss: 0.2034
#   Validation ROCAUC: 0.9249, ROCPRC: 0.8080, Macro-F1: 0.7048
#
# Epoch 160 finished. Avg Train Loss: 0.2321
#   Validation Loss: 0.2013
#   Validation ROCAUC: 0.9253, ROCPRC: 0.8103, Macro-F1: 0.6991
#   >>> New best model checkpoint saved!
#
# Epoch 161 finished. Avg Train Loss: 0.2311
#   Validation Loss: 0.2026
#   Validation ROCAUC: 0.9266, ROCPRC: 0.8084, Macro-F1: 0.6689
#
# Epoch 162 finished. Avg Train Loss: 0.2294
#   Validation Loss: 0.1998
#   Validation ROCAUC: 0.9268, ROCPRC: 0.8110, Macro-F1: 0.7016
#   >>> New best model checkpoint saved!
#
# Epoch 163 finished. Avg Train Loss: 0.2292
#   Validation Loss: 0.2001
#   Validation ROCAUC: 0.9267, ROCPRC: 0.8102, Macro-F1: 0.6840
#
# Epoch 164 finished. Avg Train Loss: 0.2306
#   Validation Loss: 0.1996
#   Validation ROCAUC: 0.9258, ROCPRC: 0.8072, Macro-F1: 0.6858
#   >>> New best model checkpoint saved!
#
# Epoch 165 finished. Avg Train Loss: 0.2292
#   Validation Loss: 0.2012
#   Validation ROCAUC: 0.9249, ROCPRC: 0.8055, Macro-F1: 0.6870
#
# Epoch 166 finished. Avg Train Loss: 0.2281
#   Validation Loss: 0.1979
#   Validation ROCAUC: 0.9273, ROCPRC: 0.8115, Macro-F1: 0.6973
#   >>> New best model checkpoint saved!
#
# Epoch 167 finished. Avg Train Loss: 0.2290
#   Validation Loss: 0.1985
#   Validation ROCAUC: 0.9291, ROCPRC: 0.8126, Macro-F1: 0.7054
#
# Epoch 168 finished. Avg Train Loss: 0.2277
#   Validation Loss: 0.1971
#   Validation ROCAUC: 0.9291, ROCPRC: 0.8122, Macro-F1: 0.7148
#   >>> New best model checkpoint saved!
#
# Epoch 169 finished. Avg Train Loss: 0.2285
#   Validation Loss: 0.1991
#   Validation ROCAUC: 0.9274, ROCPRC: 0.8098, Macro-F1: 0.6891
#
# Epoch 170 finished. Avg Train Loss: 0.2289
#   Validation Loss: 0.2007
#   Validation ROCAUC: 0.9260, ROCPRC: 0.8094, Macro-F1: 0.6988
#
# Epoch 171 finished. Avg Train Loss: 0.2300
#   Validation Loss: 0.2027
#   Validation ROCAUC: 0.9260, ROCPRC: 0.8079, Macro-F1: 0.7050
#
# Epoch 172 finished. Avg Train Loss: 0.2279
#   Validation Loss: 0.1980
#   Validation ROCAUC: 0.9288, ROCPRC: 0.8142, Macro-F1: 0.7134
#
# Epoch 173 finished. Avg Train Loss: 0.2260
#   Validation Loss: 0.1969
#   Validation ROCAUC: 0.9302, ROCPRC: 0.8144, Macro-F1: 0.6959
#   >>> New best model checkpoint saved!
#
# Epoch 174 finished. Avg Train Loss: 0.2261
#   Validation Loss: 0.1939
#   Validation ROCAUC: 0.9323, ROCPRC: 0.8199, Macro-F1: 0.7163
#   >>> New best model checkpoint saved!
#
# Epoch 175 finished. Avg Train Loss: 0.2270
#   Validation Loss: 0.2008
#   Validation ROCAUC: 0.9277, ROCPRC: 0.8080, Macro-F1: 0.6610
#
# Epoch 176 finished. Avg Train Loss: 0.2282
#   Validation Loss: 0.1963
#   Validation ROCAUC: 0.9289, ROCPRC: 0.8142, Macro-F1: 0.7073
#
# Epoch 177 finished. Avg Train Loss: 0.2279
#   Validation Loss: 0.1993
#   Validation ROCAUC: 0.9276, ROCPRC: 0.8077, Macro-F1: 0.6887
#
# Epoch 178 finished. Avg Train Loss: 0.2334
#   Validation Loss: 0.2184
#   Validation ROCAUC: 0.9144, ROCPRC: 0.7910, Macro-F1: 0.6953
#
# Epoch 179 finished. Avg Train Loss: 0.2350
#   Validation Loss: 0.2009
#   Validation ROCAUC: 0.9268, ROCPRC: 0.8117, Macro-F1: 0.7200
#
# Epoch 180 finished. Avg Train Loss: 0.2288
#   Validation Loss: 0.1980
#   Validation ROCAUC: 0.9285, ROCPRC: 0.8094, Macro-F1: 0.7183
#
# Epoch 181 finished. Avg Train Loss: 0.2275
#   Validation Loss: 0.1956
#   Validation ROCAUC: 0.9295, ROCPRC: 0.8150, Macro-F1: 0.7064
#
# Epoch 182 finished. Avg Train Loss: 0.2276
#   Validation Loss: 0.1955
#   Validation ROCAUC: 0.9297, ROCPRC: 0.8150, Macro-F1: 0.7215
#
# Epoch 183 finished. Avg Train Loss: 0.2244
#   Validation Loss: 0.1949
#   Validation ROCAUC: 0.9304, ROCPRC: 0.8136, Macro-F1: 0.7304
#
# Epoch 184 finished. Avg Train Loss: 0.2264
#   Validation Loss: 0.1995
#   Validation ROCAUC: 0.9287, ROCPRC: 0.8115, Macro-F1: 0.6900
#
# Epoch 185 finished. Avg Train Loss: 0.2310
#   Validation Loss: 0.1964
#   Validation ROCAUC: 0.9301, ROCPRC: 0.8166, Macro-F1: 0.7234
#
# Epoch 186 finished. Avg Train Loss: 0.2270
#   Validation Loss: 0.1972
#   Validation ROCAUC: 0.9288, ROCPRC: 0.8134, Macro-F1: 0.6997
#
# Epoch 187 finished. Avg Train Loss: 0.2265
#   Validation Loss: 0.1991
#   Validation ROCAUC: 0.9286, ROCPRC: 0.8127, Macro-F1: 0.6797
#
# Epoch 188 finished. Avg Train Loss: 0.2253
#   Validation Loss: 0.1945
#   Validation ROCAUC: 0.9309, ROCPRC: 0.8172, Macro-F1: 0.7030
#
# Epoch 189 finished. Avg Train Loss: 0.2241
#   Validation Loss: 0.1951
#   Validation ROCAUC: 0.9318, ROCPRC: 0.8191, Macro-F1: 0.6954
#
# Epoch 190 finished. Avg Train Loss: 0.2228
#   Validation Loss: 0.1919
#   Validation ROCAUC: 0.9329, ROCPRC: 0.8220, Macro-F1: 0.7272
#   >>> New best model checkpoint saved!
#
# Epoch 191 finished. Avg Train Loss: 0.2236
#   Validation Loss: 0.1887
#   Validation ROCAUC: 0.9348, ROCPRC: 0.8232, Macro-F1: 0.7276
#   >>> New best model checkpoint saved!
#
# Epoch 192 finished. Avg Train Loss: 0.2254
#   Validation Loss: 0.1937
#   Validation ROCAUC: 0.9315, ROCPRC: 0.8144, Macro-F1: 0.7072
#
# Epoch 193 finished. Avg Train Loss: 0.2225
#   Validation Loss: 0.1891
#   Validation ROCAUC: 0.9350, ROCPRC: 0.8233, Macro-F1: 0.7190
#
# Epoch 194 finished. Avg Train Loss: 0.2259
#   Validation Loss: 0.1917
#   Validation ROCAUC: 0.9340, ROCPRC: 0.8198, Macro-F1: 0.6907
#
# Epoch 195 finished. Avg Train Loss: 0.2231
#   Validation Loss: 0.1924
#   Validation ROCAUC: 0.9325, ROCPRC: 0.8182, Macro-F1: 0.7255
#
# Epoch 196 finished. Avg Train Loss: 0.2240
#   Validation Loss: 0.1919
#   Validation ROCAUC: 0.9320, ROCPRC: 0.8149, Macro-F1: 0.7241
#
# Epoch 197 finished. Avg Train Loss: 0.2205
#   Validation Loss: 0.1920
#   Validation ROCAUC: 0.9336, ROCPRC: 0.8222, Macro-F1: 0.7343
#
# Epoch 198 finished. Avg Train Loss: 0.2211
#   Validation Loss: 0.1882
#   Validation ROCAUC: 0.9356, ROCPRC: 0.8239, Macro-F1: 0.7157
#   >>> New best model checkpoint saved!
#
# Epoch 199 finished. Avg Train Loss: 0.2202
#   Validation Loss: 0.1846
#   Validation ROCAUC: 0.9378, ROCPRC: 0.8268, Macro-F1: 0.7408
#   >>> New best model checkpoint saved!
#
# Epoch 200 finished. Avg Train Loss: 0.2190
#   Validation Loss: 0.1861
#   Validation ROCAUC: 0.9373, ROCPRC: 0.8272, Macro-F1: 0.7269
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_200.pt
#
# Epoch 201 finished. Avg Train Loss: 0.2193
#   Validation Loss: 0.1912
#   Validation ROCAUC: 0.9337, ROCPRC: 0.8219, Macro-F1: 0.7131
#
# Epoch 202 finished. Avg Train Loss: 0.2191
#   Validation Loss: 0.1878
#   Validation ROCAUC: 0.9366, ROCPRC: 0.8249, Macro-F1: 0.7202
#
# Epoch 203 finished. Avg Train Loss: 0.2196
#   Validation Loss: 0.1875
#   Validation ROCAUC: 0.9369, ROCPRC: 0.8248, Macro-F1: 0.7360
#
# Epoch 204 finished. Avg Train Loss: 0.2191
#   Validation Loss: 0.1902
#   Validation ROCAUC: 0.9354, ROCPRC: 0.8224, Macro-F1: 0.7035
#
# Epoch 205 finished. Avg Train Loss: 0.2207
#   Validation Loss: 0.1884
#   Validation ROCAUC: 0.9352, ROCPRC: 0.8217, Macro-F1: 0.7228
#
# Epoch 206 finished. Avg Train Loss: 0.2188
#   Validation Loss: 0.1869
#   Validation ROCAUC: 0.9373, ROCPRC: 0.8250, Macro-F1: 0.7214
#
# Epoch 207 finished. Avg Train Loss: 0.2151
#   Validation Loss: 0.1852
#   Validation ROCAUC: 0.9377, ROCPRC: 0.8284, Macro-F1: 0.7510
#
# Epoch 208 finished. Avg Train Loss: 0.2167
#   Validation Loss: 0.1841
#   Validation ROCAUC: 0.9372, ROCPRC: 0.8246, Macro-F1: 0.7344
#   >>> New best model checkpoint saved!
#
# Epoch 209 finished. Avg Train Loss: 0.2159
#   Validation Loss: 0.1853
#   Validation ROCAUC: 0.9380, ROCPRC: 0.8279, Macro-F1: 0.7310
#
# Epoch 210 finished. Avg Train Loss: 0.2190
#   Validation Loss: 0.1896
#   Validation ROCAUC: 0.9346, ROCPRC: 0.8216, Macro-F1: 0.7133
#
# Epoch 211 finished. Avg Train Loss: 0.2198
#   Validation Loss: 0.1949
#   Validation ROCAUC: 0.9320, ROCPRC: 0.8156, Macro-F1: 0.7150
#
# Epoch 212 finished. Avg Train Loss: 0.2215
#   Validation Loss: 0.1876
#   Validation ROCAUC: 0.9364, ROCPRC: 0.8247, Macro-F1: 0.7205
#
# Epoch 213 finished. Avg Train Loss: 0.2158
#   Validation Loss: 0.1859
#   Validation ROCAUC: 0.9375, ROCPRC: 0.8249, Macro-F1: 0.7169
#
# Epoch 214 finished. Avg Train Loss: 0.2168
#   Validation Loss: 0.1827
#   Validation ROCAUC: 0.9401, ROCPRC: 0.8333, Macro-F1: 0.7323
#   >>> New best model checkpoint saved!
#
# Epoch 215 finished. Avg Train Loss: 0.2167
#   Validation Loss: 0.1816
#   Validation ROCAUC: 0.9403, ROCPRC: 0.8340, Macro-F1: 0.7376
#   >>> New best model checkpoint saved!
#
# Epoch 216 finished. Avg Train Loss: 0.2164
#   Validation Loss: 0.1888
#   Validation ROCAUC: 0.9346, ROCPRC: 0.8227, Macro-F1: 0.7144
#
# Epoch 217 finished. Avg Train Loss: 0.2170
#   Validation Loss: 0.1827
#   Validation ROCAUC: 0.9391, ROCPRC: 0.8310, Macro-F1: 0.7255
#
# Epoch 218 finished. Avg Train Loss: 0.2163
#   Validation Loss: 0.1826
#   Validation ROCAUC: 0.9393, ROCPRC: 0.8316, Macro-F1: 0.7324
#
# Epoch 219 finished. Avg Train Loss: 0.2142
#   Validation Loss: 0.1815
#   Validation ROCAUC: 0.9399, ROCPRC: 0.8291, Macro-F1: 0.7341
#   >>> New best model checkpoint saved!
#
# Epoch 220 finished. Avg Train Loss: 0.2149
#   Validation Loss: 0.1863
#   Validation ROCAUC: 0.9369, ROCPRC: 0.8251, Macro-F1: 0.7272
#
# Epoch 221 finished. Avg Train Loss: 0.2134
#   Validation Loss: 0.1823
#   Validation ROCAUC: 0.9386, ROCPRC: 0.8290, Macro-F1: 0.7346
#
# Epoch 222 finished. Avg Train Loss: 0.2143
#   Validation Loss: 0.1809
#   Validation ROCAUC: 0.9406, ROCPRC: 0.8310, Macro-F1: 0.7440
#   >>> New best model checkpoint saved!
#
# Epoch 223 finished. Avg Train Loss: 0.2157
#   Validation Loss: 0.1843
#   Validation ROCAUC: 0.9374, ROCPRC: 0.8252, Macro-F1: 0.7389
#
# Epoch 224 finished. Avg Train Loss: 0.2191
#   Validation Loss: 0.1828
#   Validation ROCAUC: 0.9394, ROCPRC: 0.8297, Macro-F1: 0.7230
#
# Epoch 225 finished. Avg Train Loss: 0.2162
#   Validation Loss: 0.1823
#   Validation ROCAUC: 0.9399, ROCPRC: 0.8308, Macro-F1: 0.7317
#
# Epoch 226 finished. Avg Train Loss: 0.2138
#   Validation Loss: 0.1815
#   Validation ROCAUC: 0.9392, ROCPRC: 0.8305, Macro-F1: 0.7494
#
# Epoch 227 finished. Avg Train Loss: 0.2146
#   Validation Loss: 0.1883
#   Validation ROCAUC: 0.9351, ROCPRC: 0.8240, Macro-F1: 0.7048
#
# Epoch 228 finished. Avg Train Loss: 0.2206
#   Validation Loss: 0.1846
#   Validation ROCAUC: 0.9386, ROCPRC: 0.8274, Macro-F1: 0.7188
#
# Epoch 229 finished. Avg Train Loss: 0.2139
#   Validation Loss: 0.1774
#   Validation ROCAUC: 0.9425, ROCPRC: 0.8364, Macro-F1: 0.7584
#   >>> New best model checkpoint saved!
#
# Epoch 230 finished. Avg Train Loss: 0.2139
#   Validation Loss: 0.1823
#   Validation ROCAUC: 0.9407, ROCPRC: 0.8319, Macro-F1: 0.7320
#
# Epoch 231 finished. Avg Train Loss: 0.2143
#   Validation Loss: 0.1786
#   Validation ROCAUC: 0.9420, ROCPRC: 0.8348, Macro-F1: 0.7345
#
# Epoch 232 finished. Avg Train Loss: 0.2133
#   Validation Loss: 0.1808
#   Validation ROCAUC: 0.9412, ROCPRC: 0.8333, Macro-F1: 0.7177
#
# Epoch 233 finished. Avg Train Loss: 0.2144
#   Validation Loss: 0.1804
#   Validation ROCAUC: 0.9414, ROCPRC: 0.8333, Macro-F1: 0.7290
#
# Epoch 234 finished. Avg Train Loss: 0.2109
#   Validation Loss: 0.1782
#   Validation ROCAUC: 0.9434, ROCPRC: 0.8347, Macro-F1: 0.7195
#
# Epoch 235 finished. Avg Train Loss: 0.2118
#   Validation Loss: 0.1801
#   Validation ROCAUC: 0.9408, ROCPRC: 0.8322, Macro-F1: 0.7312
#
# Epoch 236 finished. Avg Train Loss: 0.2124
#   Validation Loss: 0.1802
#   Validation ROCAUC: 0.9407, ROCPRC: 0.8303, Macro-F1: 0.7319
#
# Epoch 237 finished. Avg Train Loss: 0.2135
#   Validation Loss: 0.1770
#   Validation ROCAUC: 0.9434, ROCPRC: 0.8370, Macro-F1: 0.7484
#   >>> New best model checkpoint saved!
#
# Epoch 238 finished. Avg Train Loss: 0.2102
#   Validation Loss: 0.1805
#   Validation ROCAUC: 0.9419, ROCPRC: 0.8344, Macro-F1: 0.7291
#
# Epoch 239 finished. Avg Train Loss: 0.2126
#   Validation Loss: 0.1762
#   Validation ROCAUC: 0.9432, ROCPRC: 0.8366, Macro-F1: 0.7495
#   >>> New best model checkpoint saved!
#
# Epoch 240 finished. Avg Train Loss: 0.2107
#   Validation Loss: 0.1770
#   Validation ROCAUC: 0.9429, ROCPRC: 0.8374, Macro-F1: 0.7399
#
# Epoch 241 finished. Avg Train Loss: 0.2102
#   Validation Loss: 0.1793
#   Validation ROCAUC: 0.9420, ROCPRC: 0.8356, Macro-F1: 0.7520
#
# Epoch 242 finished. Avg Train Loss: 0.2094
#   Validation Loss: 0.1792
#   Validation ROCAUC: 0.9418, ROCPRC: 0.8333, Macro-F1: 0.7290
#
# Epoch 243 finished. Avg Train Loss: 0.2085
#   Validation Loss: 0.1770
#   Validation ROCAUC: 0.9436, ROCPRC: 0.8401, Macro-F1: 0.7327
#
# Epoch 244 finished. Avg Train Loss: 0.2108
#   Validation Loss: 0.1747
#   Validation ROCAUC: 0.9452, ROCPRC: 0.8400, Macro-F1: 0.7433
#   >>> New best model checkpoint saved!
#
# Epoch 245 finished. Avg Train Loss: 0.2086
#   Validation Loss: 0.1749
#   Validation ROCAUC: 0.9435, ROCPRC: 0.8366, Macro-F1: 0.7460
#
# Epoch 246 finished. Avg Train Loss: 0.2084
#   Validation Loss: 0.1779
#   Validation ROCAUC: 0.9424, ROCPRC: 0.8365, Macro-F1: 0.7478
#
# Epoch 247 finished. Avg Train Loss: 0.2079
#   Validation Loss: 0.1768
#   Validation ROCAUC: 0.9436, ROCPRC: 0.8383, Macro-F1: 0.7551
#
# Epoch 248 finished. Avg Train Loss: 0.2101
#   Validation Loss: 0.1752
#   Validation ROCAUC: 0.9435, ROCPRC: 0.8370, Macro-F1: 0.7507
#
# Epoch 249 finished. Avg Train Loss: 0.2109
#   Validation Loss: 0.1757
#   Validation ROCAUC: 0.9441, ROCPRC: 0.8361, Macro-F1: 0.7338
#
# Epoch 250 finished. Avg Train Loss: 0.2130
#   Validation Loss: 0.1790
#   Validation ROCAUC: 0.9411, ROCPRC: 0.8311, Macro-F1: 0.7391
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_250.pt
#
# Epoch 251 finished. Avg Train Loss: 0.2111
#   Validation Loss: 0.1756
#   Validation ROCAUC: 0.9444, ROCPRC: 0.8377, Macro-F1: 0.7508
#
# Epoch 252 finished. Avg Train Loss: 0.2105
#   Validation Loss: 0.1779
#   Validation ROCAUC: 0.9435, ROCPRC: 0.8362, Macro-F1: 0.7454
#
# Epoch 253 finished. Avg Train Loss: 0.2111
#   Validation Loss: 0.1754
#   Validation ROCAUC: 0.9451, ROCPRC: 0.8402, Macro-F1: 0.7314
#
# Epoch 254 finished. Avg Train Loss: 0.2089
#   Validation Loss: 0.1752
#   Validation ROCAUC: 0.9448, ROCPRC: 0.8389, Macro-F1: 0.7279
#
# Epoch 255 finished. Avg Train Loss: 0.2074
#   Validation Loss: 0.1735
#   Validation ROCAUC: 0.9464, ROCPRC: 0.8411, Macro-F1: 0.7405
#   >>> New best model checkpoint saved!
#
# Epoch 256 finished. Avg Train Loss: 0.2083
#   Validation Loss: 0.1753
#   Validation ROCAUC: 0.9439, ROCPRC: 0.8358, Macro-F1: 0.7534
#
# Epoch 257 finished. Avg Train Loss: 0.2059
#   Validation Loss: 0.1801
#   Validation ROCAUC: 0.9415, ROCPRC: 0.8346, Macro-F1: 0.7559
#
# Epoch 258 finished. Avg Train Loss: 0.2095
#   Validation Loss: 0.1725
#   Validation ROCAUC: 0.9456, ROCPRC: 0.8394, Macro-F1: 0.7633
#   >>> New best model checkpoint saved!
#
# Epoch 259 finished. Avg Train Loss: 0.2086
#   Validation Loss: 0.1730
#   Validation ROCAUC: 0.9453, ROCPRC: 0.8380, Macro-F1: 0.7475
#
# Epoch 260 finished. Avg Train Loss: 0.2068
#   Validation Loss: 0.1744
#   Validation ROCAUC: 0.9444, ROCPRC: 0.8377, Macro-F1: 0.7516
#
# Epoch 261 finished. Avg Train Loss: 0.2058
#   Validation Loss: 0.1703
#   Validation ROCAUC: 0.9467, ROCPRC: 0.8414, Macro-F1: 0.7615
#   >>> New best model checkpoint saved!
#
# Epoch 262 finished. Avg Train Loss: 0.2067
#   Validation Loss: 0.1734
#   Validation ROCAUC: 0.9459, ROCPRC: 0.8425, Macro-F1: 0.7437
#
# Epoch 263 finished. Avg Train Loss: 0.2086
#   Validation Loss: 0.1722
#   Validation ROCAUC: 0.9464, ROCPRC: 0.8420, Macro-F1: 0.7395
#
# Epoch 264 finished. Avg Train Loss: 0.2085
#   Validation Loss: 0.1726
#   Validation ROCAUC: 0.9458, ROCPRC: 0.8401, Macro-F1: 0.7411
#
# Epoch 265 finished. Avg Train Loss: 0.2046
#   Validation Loss: 0.1733
#   Validation ROCAUC: 0.9462, ROCPRC: 0.8429, Macro-F1: 0.7418
#
# Epoch 266 finished. Avg Train Loss: 0.2081
#   Validation Loss: 0.1775
#   Validation ROCAUC: 0.9433, ROCPRC: 0.8355, Macro-F1: 0.7340
#
# Epoch 267 finished. Avg Train Loss: 0.2068
#   Validation Loss: 0.1707
#   Validation ROCAUC: 0.9477, ROCPRC: 0.8432, Macro-F1: 0.7445
#
# Epoch 268 finished. Avg Train Loss: 0.2059
#   Validation Loss: 0.1736
#   Validation ROCAUC: 0.9461, ROCPRC: 0.8422, Macro-F1: 0.7389
#
# Epoch 269 finished. Avg Train Loss: 0.2054
#   Validation Loss: 0.1795
#   Validation ROCAUC: 0.9425, ROCPRC: 0.8314, Macro-F1: 0.7271
#
# Epoch 270 finished. Avg Train Loss: 0.2074
#   Validation Loss: 0.1754
#   Validation ROCAUC: 0.9444, ROCPRC: 0.8365, Macro-F1: 0.7530
#
# Epoch 271 finished. Avg Train Loss: 0.2083
#   Validation Loss: 0.1773
#   Validation ROCAUC: 0.9436, ROCPRC: 0.8353, Macro-F1: 0.7498
#
# Epoch 272 finished. Avg Train Loss: 0.2086
#   Validation Loss: 0.1730
#   Validation ROCAUC: 0.9457, ROCPRC: 0.8385, Macro-F1: 0.7402
#
# Epoch 273 finished. Avg Train Loss: 0.2070
#   Validation Loss: 0.1732
#   Validation ROCAUC: 0.9459, ROCPRC: 0.8395, Macro-F1: 0.7319
#
# Epoch 274 finished. Avg Train Loss: 0.2047
#   Validation Loss: 0.1718
#   Validation ROCAUC: 0.9466, ROCPRC: 0.8419, Macro-F1: 0.7531
#
# Epoch 275 finished. Avg Train Loss: 0.2043
#   Validation Loss: 0.1702
#   Validation ROCAUC: 0.9481, ROCPRC: 0.8460, Macro-F1: 0.7402
#   >>> New best model checkpoint saved!
#
# Epoch 276 finished. Avg Train Loss: 0.2041
#   Validation Loss: 0.1690
#   Validation ROCAUC: 0.9492, ROCPRC: 0.8469, Macro-F1: 0.7448
#   >>> New best model checkpoint saved!
#
# Epoch 277 finished. Avg Train Loss: 0.2023
#   Validation Loss: 0.1708
#   Validation ROCAUC: 0.9473, ROCPRC: 0.8420, Macro-F1: 0.7552
#
# Epoch 278 finished. Avg Train Loss: 0.2024
#   Validation Loss: 0.1711
#   Validation ROCAUC: 0.9467, ROCPRC: 0.8420, Macro-F1: 0.7466
#
# Epoch 279 finished. Avg Train Loss: 0.2040
#   Validation Loss: 0.1711
#   Validation ROCAUC: 0.9464, ROCPRC: 0.8411, Macro-F1: 0.7594
#
# Epoch 280 finished. Avg Train Loss: 0.2021
#   Validation Loss: 0.1697
#   Validation ROCAUC: 0.9480, ROCPRC: 0.8424, Macro-F1: 0.7470
#
# Epoch 281 finished. Avg Train Loss: 0.2025
#   Validation Loss: 0.1705
#   Validation ROCAUC: 0.9479, ROCPRC: 0.8430, Macro-F1: 0.7598
#
# Epoch 282 finished. Avg Train Loss: 0.2033
#   Validation Loss: 0.1693
#   Validation ROCAUC: 0.9484, ROCPRC: 0.8436, Macro-F1: 0.7377
#
# Epoch 283 finished. Avg Train Loss: 0.2024
#   Validation Loss: 0.1732
#   Validation ROCAUC: 0.9453, ROCPRC: 0.8398, Macro-F1: 0.7488
#
# Epoch 284 finished. Avg Train Loss: 0.2041
#   Validation Loss: 0.1680
#   Validation ROCAUC: 0.9487, ROCPRC: 0.8463, Macro-F1: 0.7551
#   >>> New best model checkpoint saved!
#
# Epoch 285 finished. Avg Train Loss: 0.1998
#   Validation Loss: 0.1683
#   Validation ROCAUC: 0.9483, ROCPRC: 0.8450, Macro-F1: 0.7603
#
# Epoch 286 finished. Avg Train Loss: 0.1999
#   Validation Loss: 0.1652
#   Validation ROCAUC: 0.9504, ROCPRC: 0.8509, Macro-F1: 0.7585
#   >>> New best model checkpoint saved!
#
# Epoch 287 finished. Avg Train Loss: 0.2000
#   Validation Loss: 0.1724
#   Validation ROCAUC: 0.9461, ROCPRC: 0.8427, Macro-F1: 0.7385
#
# Epoch 288 finished. Avg Train Loss: 0.2050
#   Validation Loss: 0.1683
#   Validation ROCAUC: 0.9479, ROCPRC: 0.8436, Macro-F1: 0.7561
#
# Epoch 289 finished. Avg Train Loss: 0.2041
#   Validation Loss: 0.1726
#   Validation ROCAUC: 0.9464, ROCPRC: 0.8432, Macro-F1: 0.7461
#
# Epoch 290 finished. Avg Train Loss: 0.2032
#   Validation Loss: 0.1684
#   Validation ROCAUC: 0.9490, ROCPRC: 0.8466, Macro-F1: 0.7479
#
# Epoch 291 finished. Avg Train Loss: 0.2028
#   Validation Loss: 0.1673
#   Validation ROCAUC: 0.9494, ROCPRC: 0.8484, Macro-F1: 0.7523
#
# Epoch 292 finished. Avg Train Loss: 0.2021
#   Validation Loss: 0.1668
#   Validation ROCAUC: 0.9490, ROCPRC: 0.8456, Macro-F1: 0.7603
#
# Epoch 293 finished. Avg Train Loss: 0.2009
#   Validation Loss: 0.1674
#   Validation ROCAUC: 0.9492, ROCPRC: 0.8472, Macro-F1: 0.7354
#
# Epoch 294 finished. Avg Train Loss: 0.2016
#   Validation Loss: 0.1657
#   Validation ROCAUC: 0.9492, ROCPRC: 0.8455, Macro-F1: 0.7585
#
# Epoch 295 finished. Avg Train Loss: 0.1992
#   Validation Loss: 0.1666
#   Validation ROCAUC: 0.9491, ROCPRC: 0.8470, Macro-F1: 0.7691
#
# Epoch 296 finished. Avg Train Loss: 0.1983
#   Validation Loss: 0.1663
#   Validation ROCAUC: 0.9497, ROCPRC: 0.8466, Macro-F1: 0.7625
#
# Epoch 297 finished. Avg Train Loss: 0.2020
#   Validation Loss: 0.1646
#   Validation ROCAUC: 0.9515, ROCPRC: 0.8500, Macro-F1: 0.7568
#   >>> New best model checkpoint saved!
#
# Epoch 298 finished. Avg Train Loss: 0.1992
#   Validation Loss: 0.1675
#   Validation ROCAUC: 0.9491, ROCPRC: 0.8471, Macro-F1: 0.7570
#
# Epoch 299 finished. Avg Train Loss: 0.2001
#   Validation Loss: 0.1665
#   Validation ROCAUC: 0.9498, ROCPRC: 0.8474, Macro-F1: 0.7653
#
# Epoch 300 finished. Avg Train Loss: 0.1998
#   Validation Loss: 0.1680
#   Validation ROCAUC: 0.9487, ROCPRC: 0.8460, Macro-F1: 0.7502
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_300.pt
#
# Epoch 301 finished. Avg Train Loss: 0.2028
#   Validation Loss: 0.1666
#   Validation ROCAUC: 0.9493, ROCPRC: 0.8473, Macro-F1: 0.7515
#
# Epoch 302 finished. Avg Train Loss: 0.2011
#   Validation Loss: 0.1673
#   Validation ROCAUC: 0.9500, ROCPRC: 0.8485, Macro-F1: 0.7670
#
# Epoch 303 finished. Avg Train Loss: 0.1979
#   Validation Loss: 0.1620
#   Validation ROCAUC: 0.9521, ROCPRC: 0.8525, Macro-F1: 0.7836
#   >>> New best model checkpoint saved!
#
# Epoch 304 finished. Avg Train Loss: 0.1987
#   Validation Loss: 0.1651
#   Validation ROCAUC: 0.9503, ROCPRC: 0.8509, Macro-F1: 0.7570
#
# Epoch 305 finished. Avg Train Loss: 0.2008
#   Validation Loss: 0.1642
#   Validation ROCAUC: 0.9502, ROCPRC: 0.8497, Macro-F1: 0.7601
#
# Epoch 306 finished. Avg Train Loss: 0.1998
#   Validation Loss: 0.1644
#   Validation ROCAUC: 0.9509, ROCPRC: 0.8511, Macro-F1: 0.7651
#
# Epoch 307 finished. Avg Train Loss: 0.1989
#   Validation Loss: 0.1660
#   Validation ROCAUC: 0.9506, ROCPRC: 0.8485, Macro-F1: 0.7506
#
# Epoch 308 finished. Avg Train Loss: 0.1975
#   Validation Loss: 0.1650
#   Validation ROCAUC: 0.9501, ROCPRC: 0.8482, Macro-F1: 0.7589
#
# Epoch 309 finished. Avg Train Loss: 0.2009
#   Validation Loss: 0.1633
#   Validation ROCAUC: 0.9513, ROCPRC: 0.8489, Macro-F1: 0.7571
#
# Epoch 310 finished. Avg Train Loss: 0.1984
#   Validation Loss: 0.1598
#   Validation ROCAUC: 0.9540, ROCPRC: 0.8559, Macro-F1: 0.7635
#   >>> New best model checkpoint saved!
#
# Epoch 311 finished. Avg Train Loss: 0.1969
#   Validation Loss: 0.1643
#   Validation ROCAUC: 0.9517, ROCPRC: 0.8512, Macro-F1: 0.7513
#
# Epoch 312 finished. Avg Train Loss: 0.1969
#   Validation Loss: 0.1639
#   Validation ROCAUC: 0.9509, ROCPRC: 0.8508, Macro-F1: 0.7603
#
# Epoch 313 finished. Avg Train Loss: 0.1973
#   Validation Loss: 0.1606
#   Validation ROCAUC: 0.9533, ROCPRC: 0.8545, Macro-F1: 0.7746
#
# Epoch 314 finished. Avg Train Loss: 0.1967
#   Validation Loss: 0.1636
#   Validation ROCAUC: 0.9511, ROCPRC: 0.8499, Macro-F1: 0.7595
#
# Epoch 315 finished. Avg Train Loss: 0.1994
#   Validation Loss: 0.1640
#   Validation ROCAUC: 0.9510, ROCPRC: 0.8507, Macro-F1: 0.7596
#
# Epoch 316 finished. Avg Train Loss: 0.1962
#   Validation Loss: 0.1641
#   Validation ROCAUC: 0.9511, ROCPRC: 0.8514, Macro-F1: 0.7760
#
# Epoch 317 finished. Avg Train Loss: 0.1942
#   Validation Loss: 0.1624
#   Validation ROCAUC: 0.9516, ROCPRC: 0.8500, Macro-F1: 0.7684
#
# Epoch 318 finished. Avg Train Loss: 0.1930
#   Validation Loss: 0.1588
#   Validation ROCAUC: 0.9539, ROCPRC: 0.8571, Macro-F1: 0.7620
#   >>> New best model checkpoint saved!
#
# Epoch 319 finished. Avg Train Loss: 0.1925
#   Validation Loss: 0.1580
#   Validation ROCAUC: 0.9547, ROCPRC: 0.8556, Macro-F1: 0.7751
#   >>> New best model checkpoint saved!
#
# Epoch 320 finished. Avg Train Loss: 0.1930
#   Validation Loss: 0.1609
#   Validation ROCAUC: 0.9526, ROCPRC: 0.8521, Macro-F1: 0.7708
#
# Epoch 321 finished. Avg Train Loss: 0.1934
#   Validation Loss: 0.1579
#   Validation ROCAUC: 0.9550, ROCPRC: 0.8570, Macro-F1: 0.7605
#   >>> New best model checkpoint saved!
#
# Epoch 322 finished. Avg Train Loss: 0.1943
#   Validation Loss: 0.1569
#   Validation ROCAUC: 0.9546, ROCPRC: 0.8568, Macro-F1: 0.7751
#   >>> New best model checkpoint saved!
#
# Epoch 323 finished. Avg Train Loss: 0.1940
#   Validation Loss: 0.1617
#   Validation ROCAUC: 0.9532, ROCPRC: 0.8524, Macro-F1: 0.7661
#
# Epoch 324 finished. Avg Train Loss: 0.1944
#   Validation Loss: 0.1609
#   Validation ROCAUC: 0.9526, ROCPRC: 0.8530, Macro-F1: 0.7694
#
# Epoch 325 finished. Avg Train Loss: 0.1936
#   Validation Loss: 0.1611
#   Validation ROCAUC: 0.9530, ROCPRC: 0.8537, Macro-F1: 0.7734
#
# Epoch 326 finished. Avg Train Loss: 0.1938
#   Validation Loss: 0.1611
#   Validation ROCAUC: 0.9532, ROCPRC: 0.8561, Macro-F1: 0.7656
#
# Epoch 327 finished. Avg Train Loss: 0.1940
#   Validation Loss: 0.1583
#   Validation ROCAUC: 0.9549, ROCPRC: 0.8566, Macro-F1: 0.7533
#
# Epoch 328 finished. Avg Train Loss: 0.1911
#   Validation Loss: 0.1588
#   Validation ROCAUC: 0.9548, ROCPRC: 0.8583, Macro-F1: 0.7490
#
# Epoch 329 finished. Avg Train Loss: 0.1929
#   Validation Loss: 0.1604
#   Validation ROCAUC: 0.9539, ROCPRC: 0.8553, Macro-F1: 0.7555
#
# Epoch 330 finished. Avg Train Loss: 0.1939
#   Validation Loss: 0.1593
#   Validation ROCAUC: 0.9539, ROCPRC: 0.8565, Macro-F1: 0.7763
#
# Epoch 331 finished. Avg Train Loss: 0.1955
#   Validation Loss: 0.1623
#   Validation ROCAUC: 0.9524, ROCPRC: 0.8510, Macro-F1: 0.7538
#
# Epoch 332 finished. Avg Train Loss: 0.1953
#   Validation Loss: 0.1627
#   Validation ROCAUC: 0.9529, ROCPRC: 0.8524, Macro-F1: 0.7783
#
# Epoch 333 finished. Avg Train Loss: 0.1923
#   Validation Loss: 0.1562
#   Validation ROCAUC: 0.9559, ROCPRC: 0.8589, Macro-F1: 0.7727
# ...
#   Validation Loss: 0.1189
#   Validation ROCAUC: 0.9749, ROCPRC: 0.9000, Macro-F1: 0.8260
#
# Epoch 764 finished. Avg Train Loss: 0.1564
#   Validation Loss: 0.1203
#   Validation ROCAUC: 0.9738, ROCPRC: 0.8977, Macro-F1: 0.8288
#
# Epoch 765 finished. Avg Train Loss: 0.1587
#   Validation Loss: 0.1219
#   Validation ROCAUC: 0.9734, ROCPRC: 0.8961, Macro-F1: 0.8321
#
# Epoch 766 finished. Avg Train Loss: 0.1605
#   Validation Loss: 0.1204
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8980, Macro-F1: 0.8289
#
# Epoch 767 finished. Avg Train Loss: 0.1587
#   Validation Loss: 0.1227
#   Validation ROCAUC: 0.9732, ROCPRC: 0.8953, Macro-F1: 0.8179
#
# Epoch 768 finished. Avg Train Loss: 0.1571
#   Validation Loss: 0.1199
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8969, Macro-F1: 0.8262
#
# Epoch 769 finished. Avg Train Loss: 0.1589
#   Validation Loss: 0.1210
#   Validation ROCAUC: 0.9742, ROCPRC: 0.8990, Macro-F1: 0.8255
#
# Epoch 770 finished. Avg Train Loss: 0.1672
#   Validation Loss: 0.1212
#   Validation ROCAUC: 0.9739, ROCPRC: 0.8967, Macro-F1: 0.8237
#
# Epoch 771 finished. Avg Train Loss: 0.1601
#   Validation Loss: 0.1192
#   Validation ROCAUC: 0.9742, ROCPRC: 0.8978, Macro-F1: 0.8277
#
# Epoch 772 finished. Avg Train Loss: 0.1590
#   Validation Loss: 0.1211
#   Validation ROCAUC: 0.9736, ROCPRC: 0.8959, Macro-F1: 0.8295
#
# Epoch 773 finished. Avg Train Loss: 0.1580
#   Validation Loss: 0.1210
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8978, Macro-F1: 0.8314
#
# Epoch 774 finished. Avg Train Loss: 0.1587
#   Validation Loss: 0.1200
#   Validation ROCAUC: 0.9741, ROCPRC: 0.8977, Macro-F1: 0.8321
#
# Epoch 775 finished. Avg Train Loss: 0.1574
#   Validation Loss: 0.1192
#   Validation ROCAUC: 0.9743, ROCPRC: 0.8985, Macro-F1: 0.8325
#
# Epoch 776 finished. Avg Train Loss: 0.1560
#   Validation Loss: 0.1186
#   Validation ROCAUC: 0.9748, ROCPRC: 0.9005, Macro-F1: 0.8305
#
# Epoch 777 finished. Avg Train Loss: 0.1561
#   Validation Loss: 0.1184
#   Validation ROCAUC: 0.9750, ROCPRC: 0.8993, Macro-F1: 0.8363
#
# Epoch 778 finished. Avg Train Loss: 0.1547
#   Validation Loss: 0.1165
#   Validation ROCAUC: 0.9753, ROCPRC: 0.9001, Macro-F1: 0.8351
#   >>> New best model checkpoint saved!
#
# Epoch 779 finished. Avg Train Loss: 0.1553
#   Validation Loss: 0.1207
#   Validation ROCAUC: 0.9739, ROCPRC: 0.8971, Macro-F1: 0.8268
#
# Epoch 780 finished. Avg Train Loss: 0.1601
#   Validation Loss: 0.1196
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8975, Macro-F1: 0.8293
#
# Epoch 781 finished. Avg Train Loss: 0.1595
#   Validation Loss: 0.1244
#   Validation ROCAUC: 0.9723, ROCPRC: 0.8927, Macro-F1: 0.8232
#
# Epoch 782 finished. Avg Train Loss: 0.1623
#   Validation Loss: 0.1195
#   Validation ROCAUC: 0.9742, ROCPRC: 0.8971, Macro-F1: 0.8333
#
# Epoch 783 finished. Avg Train Loss: 0.1587
#   Validation Loss: 0.1200
#   Validation ROCAUC: 0.9741, ROCPRC: 0.8980, Macro-F1: 0.8281
#
# Epoch 784 finished. Avg Train Loss: 0.1594
#   Validation Loss: 0.1199
#   Validation ROCAUC: 0.9743, ROCPRC: 0.8976, Macro-F1: 0.8354
#
# Epoch 785 finished. Avg Train Loss: 0.1601
#   Validation Loss: 0.1204
#   Validation ROCAUC: 0.9743, ROCPRC: 0.9007, Macro-F1: 0.8178
#
# Epoch 786 finished. Avg Train Loss: 0.1573
#   Validation Loss: 0.1190
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8983, Macro-F1: 0.8425
#
# Epoch 787 finished. Avg Train Loss: 0.1567
#   Validation Loss: 0.1167
#   Validation ROCAUC: 0.9753, ROCPRC: 0.9007, Macro-F1: 0.8314
#
# Epoch 788 finished. Avg Train Loss: 0.1578
#   Validation Loss: 0.1208
#   Validation ROCAUC: 0.9738, ROCPRC: 0.8966, Macro-F1: 0.8295
#
# Epoch 789 finished. Avg Train Loss: 0.1597
#   Validation Loss: 0.1204
#   Validation ROCAUC: 0.9743, ROCPRC: 0.8981, Macro-F1: 0.8358
#
# Epoch 790 finished. Avg Train Loss: 0.1609
#   Validation Loss: 0.1211
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8969, Macro-F1: 0.8321
#
# Epoch 791 finished. Avg Train Loss: 0.1632
#   Validation Loss: 0.1198
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8954, Macro-F1: 0.8347
#
# Epoch 792 finished. Avg Train Loss: 0.1601
#   Validation Loss: 0.1212
#   Validation ROCAUC: 0.9737, ROCPRC: 0.8957, Macro-F1: 0.8319
#
# Epoch 793 finished. Avg Train Loss: 0.1604
#   Validation Loss: 0.1195
#   Validation ROCAUC: 0.9746, ROCPRC: 0.8989, Macro-F1: 0.8324
#
# Epoch 794 finished. Avg Train Loss: 0.1587
#   Validation Loss: 0.1226
#   Validation ROCAUC: 0.9735, ROCPRC: 0.8967, Macro-F1: 0.8182
#
# Epoch 795 finished. Avg Train Loss: 0.1584
#   Validation Loss: 0.1163
#   Validation ROCAUC: 0.9754, ROCPRC: 0.8999, Macro-F1: 0.8367
#   >>> New best model checkpoint saved!
#
# Epoch 796 finished. Avg Train Loss: 0.1581
#   Validation Loss: 0.1194
#   Validation ROCAUC: 0.9744, ROCPRC: 0.8982, Macro-F1: 0.8280
#
# Epoch 797 finished. Avg Train Loss: 0.1597
#   Validation Loss: 0.1232
#   Validation ROCAUC: 0.9736, ROCPRC: 0.8972, Macro-F1: 0.8091
#
# Epoch 798 finished. Avg Train Loss: 0.1605
#   Validation Loss: 0.1191
#   Validation ROCAUC: 0.9746, ROCPRC: 0.9000, Macro-F1: 0.8328
#
# Epoch 799 finished. Avg Train Loss: 0.1743
#   Validation Loss: 0.1349
#   Validation ROCAUC: 0.9691, ROCPRC: 0.8842, Macro-F1: 0.8028
#
# Epoch 800 finished. Avg Train Loss: 0.1661
#   Validation Loss: 0.1226
#   Validation ROCAUC: 0.9735, ROCPRC: 0.8954, Macro-F1: 0.8121
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_800.pt
#
# Epoch 801 finished. Avg Train Loss: 0.1610
#   Validation Loss: 0.1195
#   Validation ROCAUC: 0.9743, ROCPRC: 0.8992, Macro-F1: 0.8288
#
# Epoch 802 finished. Avg Train Loss: 0.1619
#   Validation Loss: 0.1217
#   Validation ROCAUC: 0.9739, ROCPRC: 0.8969, Macro-F1: 0.8268
#
# Epoch 803 finished. Avg Train Loss: 0.1652
#   Validation Loss: 0.1208
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8973, Macro-F1: 0.8334
#
# Epoch 804 finished. Avg Train Loss: 0.1648
#   Validation Loss: 0.1246
#   Validation ROCAUC: 0.9726, ROCPRC: 0.8935, Macro-F1: 0.8270
#
# Epoch 805 finished. Avg Train Loss: 0.1639
#   Validation Loss: 0.1236
#   Validation ROCAUC: 0.9729, ROCPRC: 0.8929, Macro-F1: 0.8298
#
# Epoch 806 finished. Avg Train Loss: 0.1624
#   Validation Loss: 0.1200
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8982, Macro-F1: 0.8342
#
# Epoch 807 finished. Avg Train Loss: 0.1609
#   Validation Loss: 0.1227
#   Validation ROCAUC: 0.9729, ROCPRC: 0.8954, Macro-F1: 0.8262
#
# Epoch 808 finished. Avg Train Loss: 0.1591
#   Validation Loss: 0.1205
#   Validation ROCAUC: 0.9743, ROCPRC: 0.8978, Macro-F1: 0.8367
#
# Epoch 809 finished. Avg Train Loss: 0.1609
#   Validation Loss: 0.1190
#   Validation ROCAUC: 0.9746, ROCPRC: 0.8980, Macro-F1: 0.8259
#
# Epoch 810 finished. Avg Train Loss: 0.1586
#   Validation Loss: 0.1184
#   Validation ROCAUC: 0.9746, ROCPRC: 0.8970, Macro-F1: 0.8301
#
# Epoch 811 finished. Avg Train Loss: 0.1574
#   Validation Loss: 0.1179
#   Validation ROCAUC: 0.9748, ROCPRC: 0.8977, Macro-F1: 0.8348
#
# Epoch 812 finished. Avg Train Loss: 0.1578
#   Validation Loss: 0.1195
#   Validation ROCAUC: 0.9745, ROCPRC: 0.8984, Macro-F1: 0.8358
#
# Epoch 813 finished. Avg Train Loss: 0.1616
#   Validation Loss: 0.1261
#   Validation ROCAUC: 0.9728, ROCPRC: 0.8958, Macro-F1: 0.8109
#
# Epoch 814 finished. Avg Train Loss: 0.1618
#   Validation Loss: 0.1209
#   Validation ROCAUC: 0.9739, ROCPRC: 0.8977, Macro-F1: 0.8316
#
# Epoch 815 finished. Avg Train Loss: 0.1589
#   Validation Loss: 0.1205
#   Validation ROCAUC: 0.9746, ROCPRC: 0.8974, Macro-F1: 0.8295
#
# Epoch 816 finished. Avg Train Loss: 0.1581
#   Validation Loss: 0.1186
#   Validation ROCAUC: 0.9751, ROCPRC: 0.8997, Macro-F1: 0.8410
#
# Epoch 817 finished. Avg Train Loss: 0.1564
#   Validation Loss: 0.1185
#   Validation ROCAUC: 0.9749, ROCPRC: 0.8977, Macro-F1: 0.8301
#
# Epoch 818 finished. Avg Train Loss: 0.1550
#   Validation Loss: 0.1173
#   Validation ROCAUC: 0.9755, ROCPRC: 0.9005, Macro-F1: 0.8357
#
# Epoch 819 finished. Avg Train Loss: 0.1561
#   Validation Loss: 0.1166
#   Validation ROCAUC: 0.9756, ROCPRC: 0.9011, Macro-F1: 0.8381
#
# Epoch 820 finished. Avg Train Loss: 0.1543
#   Validation Loss: 0.1157
#   Validation ROCAUC: 0.9758, ROCPRC: 0.9034, Macro-F1: 0.8372
#   >>> New best model checkpoint saved!
#
# Epoch 821 finished. Avg Train Loss: 0.1550
#   Validation Loss: 0.1158
#   Validation ROCAUC: 0.9759, ROCPRC: 0.9019, Macro-F1: 0.8391
#
# Epoch 822 finished. Avg Train Loss: 0.1557
#   Validation Loss: 0.1194
#   Validation ROCAUC: 0.9743, ROCPRC: 0.8968, Macro-F1: 0.8213
#
# Epoch 823 finished. Avg Train Loss: 0.1547
#   Validation Loss: 0.1151
#   Validation ROCAUC: 0.9763, ROCPRC: 0.9025, Macro-F1: 0.8410
#   >>> New best model checkpoint saved!
#
# Epoch 824 finished. Avg Train Loss: 0.1554
#   Validation Loss: 0.1201
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8976, Macro-F1: 0.8298
#
# Epoch 825 finished. Avg Train Loss: 0.1558
#   Validation Loss: 0.1160
#   Validation ROCAUC: 0.9759, ROCPRC: 0.9025, Macro-F1: 0.8385
#
# Epoch 826 finished. Avg Train Loss: 0.1563
#   Validation Loss: 0.1168
#   Validation ROCAUC: 0.9753, ROCPRC: 0.8998, Macro-F1: 0.8347
#
# Epoch 827 finished. Avg Train Loss: 0.1573
#   Validation Loss: 0.1175
#   Validation ROCAUC: 0.9748, ROCPRC: 0.8989, Macro-F1: 0.8331
#
# Epoch 828 finished. Avg Train Loss: 0.1551
#   Validation Loss: 0.1152
#   Validation ROCAUC: 0.9763, ROCPRC: 0.9013, Macro-F1: 0.8305
#
# Epoch 829 finished. Avg Train Loss: 0.1545
#   Validation Loss: 0.1130
#   Validation ROCAUC: 0.9768, ROCPRC: 0.9036, Macro-F1: 0.8437
#   >>> New best model checkpoint saved!
#
# Epoch 830 finished. Avg Train Loss: 0.1540
#   Validation Loss: 0.1169
#   Validation ROCAUC: 0.9757, ROCPRC: 0.9019, Macro-F1: 0.8291
#
# Epoch 831 finished. Avg Train Loss: 0.1542
#   Validation Loss: 0.1143
#   Validation ROCAUC: 0.9764, ROCPRC: 0.9046, Macro-F1: 0.8425
#
# Epoch 832 finished. Avg Train Loss: 0.1557
#   Validation Loss: 0.1155
#   Validation ROCAUC: 0.9762, ROCPRC: 0.9016, Macro-F1: 0.8360
#
# Epoch 833 finished. Avg Train Loss: 0.1560
#   Validation Loss: 0.1175
#   Validation ROCAUC: 0.9754, ROCPRC: 0.9006, Macro-F1: 0.8257
#
# Epoch 834 finished. Avg Train Loss: 0.1549
#   Validation Loss: 0.1182
#   Validation ROCAUC: 0.9744, ROCPRC: 0.8965, Macro-F1: 0.8425
#
# Epoch 835 finished. Avg Train Loss: 0.1556
#   Validation Loss: 0.1227
#   Validation ROCAUC: 0.9729, ROCPRC: 0.8931, Macro-F1: 0.8317
#
# Epoch 836 finished. Avg Train Loss: 0.1601
#   Validation Loss: 0.1185
#   Validation ROCAUC: 0.9757, ROCPRC: 0.9013, Macro-F1: 0.8213
#
# Epoch 837 finished. Avg Train Loss: 0.1551
#   Validation Loss: 0.1186
#   Validation ROCAUC: 0.9748, ROCPRC: 0.8995, Macro-F1: 0.8397
#
# Epoch 838 finished. Avg Train Loss: 0.1567
#   Validation Loss: 0.1189
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8986, Macro-F1: 0.8326
#
# Epoch 839 finished. Avg Train Loss: 0.1584
#   Validation Loss: 0.1164
#   Validation ROCAUC: 0.9755, ROCPRC: 0.9010, Macro-F1: 0.8398
#
# Epoch 840 finished. Avg Train Loss: 0.1569
#   Validation Loss: 0.1169
#   Validation ROCAUC: 0.9753, ROCPRC: 0.8987, Macro-F1: 0.8377
#
# Epoch 841 finished. Avg Train Loss: 0.1653
#   Validation Loss: 0.1299
#   Validation ROCAUC: 0.9705, ROCPRC: 0.8898, Macro-F1: 0.8082
#
# Epoch 842 finished. Avg Train Loss: 0.1712
#   Validation Loss: 0.1250
#   Validation ROCAUC: 0.9724, ROCPRC: 0.8943, Macro-F1: 0.8288
#
# Epoch 843 finished. Avg Train Loss: 0.1672
#   Validation Loss: 0.1219
#   Validation ROCAUC: 0.9737, ROCPRC: 0.8972, Macro-F1: 0.8249
#
# Epoch 844 finished. Avg Train Loss: 0.1643
#   Validation Loss: 0.1220
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8986, Macro-F1: 0.8217
#
# Epoch 845 finished. Avg Train Loss: 0.1627
#   Validation Loss: 0.1213
#   Validation ROCAUC: 0.9736, ROCPRC: 0.8951, Macro-F1: 0.8277
#
# Epoch 846 finished. Avg Train Loss: 0.1694
#   Validation Loss: 0.1254
#   Validation ROCAUC: 0.9720, ROCPRC: 0.8918, Macro-F1: 0.8243
#
# Epoch 847 finished. Avg Train Loss: 0.1640
#   Validation Loss: 0.1197
#   Validation ROCAUC: 0.9742, ROCPRC: 0.8975, Macro-F1: 0.8316
#
# Epoch 848 finished. Avg Train Loss: 0.1625
#   Validation Loss: 0.1206
#   Validation ROCAUC: 0.9744, ROCPRC: 0.8981, Macro-F1: 0.8265
#
# Epoch 849 finished. Avg Train Loss: 0.1613
#   Validation Loss: 0.1188
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8973, Macro-F1: 0.8370
#
# Epoch 850 finished. Avg Train Loss: 0.1595
#   Validation Loss: 0.1196
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8992, Macro-F1: 0.8288
#   Saved epoch checkpoint to checkpoints/checkpoint_epoch_850.pt
#
# Epoch 851 finished. Avg Train Loss: 0.1595
#   Validation Loss: 0.1181
#   Validation ROCAUC: 0.9748, ROCPRC: 0.8974, Macro-F1: 0.8310
#
# Epoch 852 finished. Avg Train Loss: 0.1617
#   Validation Loss: 0.1207
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8963, Macro-F1: 0.8407
#
# Epoch 853 finished. Avg Train Loss: 0.1608
#   Validation Loss: 0.1190
#   Validation ROCAUC: 0.9744, ROCPRC: 0.8976, Macro-F1: 0.8285
#
# Epoch 854 finished. Avg Train Loss: 0.1594
#   Validation Loss: 0.1208
#   Validation ROCAUC: 0.9740, ROCPRC: 0.8973, Macro-F1: 0.8249
#
# Epoch 855 finished. Avg Train Loss: 0.1611
#   Validation Loss: 0.1182
#   Validation ROCAUC: 0.9751, ROCPRC: 0.8999, Macro-F1: 0.8375
#
# Epoch 856 finished. Avg Train Loss: 0.1575
#   Validation Loss: 0.1193
#   Validation ROCAUC: 0.9748, ROCPRC: 0.8983, Macro-F1: 0.8283
#
# Epoch 857 finished. Avg Train Loss: 0.1587
#   Validation Loss: 0.1185
#   Validation ROCAUC: 0.9752, ROCPRC: 0.8988, Macro-F1: 0.8250
#
# Epoch 858 finished. Avg Train Loss: 0.1559
#   Validation Loss: 0.1168
#   Validation ROCAUC: 0.9759, ROCPRC: 0.9005, Macro-F1: 0.8239
#
# Epoch 859 finished. Avg Train Loss: 0.1921
#   Validation Loss: 0.1321
#   Validation ROCAUC: 0.9698, ROCPRC: 0.8879, Macro-F1: 0.7990
#
# Epoch 860 finished. Avg Train Loss: 0.1624
#   Validation Loss: 0.1185
#   Validation ROCAUC: 0.9747, ROCPRC: 0.8988, Macro-F1: 0.8339
#
# Epoch 861 finished. Avg Train Loss: 0.1583
#   Validation Loss: 0.1162
#   Validation ROCAUC: 0.9758, ROCPRC: 0.9022, Macro-F1: 0.8452
#
# Epoch 862 finished. Avg Train Loss: 0.1581
#   Validation Loss: 0.1184
#   Validation ROCAUC: 0.9748, ROCPRC: 0.8995, Macro-F1: 0.8311
#
# Epoch 863 finished. Avg Train Loss: 0.1576
#   Validation Loss: 0.1175
#   Validation ROCAUC: 0.9751, ROCPRC: 0.9001, Macro-F1: 0.8273
#
# Epoch 864 finished. Avg Train Loss: 0.1571
#   Validation Loss: 0.1167
#   Validation ROCAUC: 0.9756, ROCPRC: 0.9002, Macro-F1: 0.8380
#
# Epoch 865 finished. Avg Train Loss: 0.1563
#   Validation Loss: 0.1160
#   Validation ROCAUC: 0.9759, ROCPRC: 0.9007, Macro-F1: 0.8415
#
# Epoch 866 finished. Avg Train Loss: 0.1572
#   Validation Loss: 0.1153
#   Validation ROCAUC: 0.9761, ROCPRC: 0.9030, Macro-F1: 0.8368
#
# Epoch 867 finished. Avg Train Loss: 0.1565
#   Validation Loss: 0.1159
#   Validation ROCAUC: 0.9759, ROCPRC: 0.9023, Macro-F1: 0.8370
#
# Epoch 868 finished. Avg Train Loss: 0.1546
#   Validation Loss: 0.1156
#   Validation ROCAUC: 0.9758, ROCPRC: 0.9007, Macro-F1: 0.8313
#
# Epoch 869 finished. Avg Train Loss: 0.1538
#   Validation Loss: 0.1136
#   Validation ROCAUC: 0.9767, ROCPRC: 0.9042, Macro-F1: 0.8431
#
# Epoch 870 finished. Avg Train Loss: 0.1560
#   Validation Loss: 0.1153
#   Validation ROCAUC: 0.9762, ROCPRC: 0.9011, Macro-F1: 0.8330
#
# Epoch 871 finished. Avg Train Loss: 0.1564
#   Validation Loss: 0.1152
#   Validation ROCAUC: 0.9758, ROCPRC: 0.9002, Macro-F1: 0.8377
#
# Epoch 872 finished. Avg Train Loss: 0.1531
#   Validation Loss: 0.1146
#   Validation ROCAUC: 0.9764, ROCPRC: 0.9024, Macro-F1: 0.8265
#
# Epoch 873 finished. Avg Train Loss: 0.1530
#   Validation Loss: 0.1150
#   Validation ROCAUC: 0.9763, ROCPRC: 0.9017, Macro-F1: 0.8373
#
# Epoch 874 finished. Avg Train Loss: 0.1534
#   Validation Loss: 0.1152
#   Validation ROCAUC: 0.9765, ROCPRC: 0.9034, Macro-F1: 0.8420
#
# Epoch 875 finished. Avg Train Loss: 0.1531
#   Validation Loss: 0.1175
#   Validation ROCAUC: 0.9755, ROCPRC: 0.9009, Macro-F1: 0.8296
#
# Epoch 876 finished. Avg Train Loss: 0.1543
#   Validation Loss: 0.1154
#   Validation ROCAUC: 0.9761, ROCPRC: 0.9026, Macro-F1: 0.8302
#
# Epoch 877 finished. Avg Train Loss: 0.1542
#   Validation Loss: 0.1161
#   Validation ROCAUC: 0.9759, ROCPRC: 0.9010, Macro-F1: 0.8291
#
# Epoch 878 finished. Avg Train Loss: 0.1531
#   Validation Loss: 0.1136
#   Validation ROCAUC: 0.9766, ROCPRC: 0.9037, Macro-F1: 0.8380
#
# Epoch 879 finished. Avg Train Loss: 0.1540
#   Validation Loss: 0.1145
#   Validation ROCAUC: 0.9763, ROCPRC: 0.9022, Macro-F1: 0.8377
# Early stopping triggered after 879 epochs.
#
# --- Starting Final Test Evaluation ---
#   Test Loss: 0.1147
#   Final Test ROCAUC (All 144 Tissues): 0.9757
#   Final Test ROCAUC (105 Leaf Tissues): 0.9722
#   Goal Achieved! Test ROCAUC (0.9722) exceeded target (0.7560).

# %% [markdown]
# **Plotting losses**

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(history_train_loss) + 1), history_train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(history_val_loss) + 1), history_val_loss, label='Validation Loss', color='orange')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# **Goal achieved, on to other metrics**
